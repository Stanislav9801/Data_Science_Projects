# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-подготовка-окружения" data-toc-modified-id="Импорт-библиотек-и-подготовка-окружения-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Импорт библиотек и подготовка окружения</a></span></li><li><span><a href="#1.-Подготовка" data-toc-modified-id="1.-Подготовка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1. Подготовка</a></span><ul class="toc-item"><li><span><a href="#1.1-Загрузим-данные" data-toc-modified-id="1.1-Загрузим-данные-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>1.1 Загрузим данные</a></span></li><li><span><a href="#1.2-Произведем-токенизацию-и-превращение-предложений-в-эмбеддинги-при-помощи-BERT" data-toc-modified-id="1.2-Произведем-токенизацию-и-превращение-предложений-в-эмбеддинги-при-помощи-BERT-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>1.2 Произведем токенизацию и превращение предложений в эмбеддинги при помощи BERT</a></span></li><li><span><a href="#1.3-Разделим-данные-на-тренировочную-и-тестовую-выборку." data-toc-modified-id="1.3-Разделим-данные-на-тренировочную-и-тестовую-выборку.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>1.3 Разделим данные на тренировочную и тестовую выборку.</a></span></li></ul></li><li><span><a href="#2.-Обучение" data-toc-modified-id="2.-Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>2. Обучение</a></span><ul class="toc-item"><li><span><a href="#2.1-Модель-логистической-регрессии" data-toc-modified-id="2.1-Модель-логистической-регрессии-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>2.1 Модель логистической регрессии</a></span></li><li><span><a href="#2.2-Модель-случайного-леса" data-toc-modified-id="2.2-Модель-случайного-леса-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>2.2 Модель случайного леса</a></span></li><li><span><a href="#2.3-Модель-градиентного-бустинга" data-toc-modified-id="2.3-Модель-градиентного-бустинга-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>2.3 Модель градиентного бустинга</a></span></li><li><span><a href="#2.4-Нейронная-сеть" data-toc-modified-id="2.4-Нейронная-сеть-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>2.4 Нейронная сеть</a></span></li><li><span><a href="#2.5-Резюме" data-toc-modified-id="2.5-Резюме-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>2.5 Резюме</a></span></li></ul></li><li><span><a href="#3.-Подбор-гиперпараметров" data-toc-modified-id="3.-Подбор-гиперпараметров-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>3. Подбор гиперпараметров</a></span></li><li><span><a href="#4.-Проверка-на-тестовой-выборке" data-toc-modified-id="4.-Проверка-на-тестовой-выборке-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>4. Проверка на тестовой выборке</a></span></li><li><span><a href="#5.-Выводы" data-toc-modified-id="5.-Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>5. Выводы</a></span></li></ul></div>

# %% [markdown]
# # Проект для «Викишоп» с BERT

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# Обучите модель классифицировать комментарии на позитивные и негативные. В вашем распоряжении набор данных с разметкой о токсичности правок.
#
# Постройте модель со значением метрики качества *F1* не меньше 0.75.
#
# **Описание данных**
#
# Данные находятся в файле `toxic_comments.csv`. Столбец *text* содержит текст комментария, а *toxic* — целевой признак.

# %% [markdown]
# ## Импорт библиотек и подготовка окружения

# %%
# !pip install transformers
# !pip install catboost
# !pip install optuna

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import torch as t
import pickle
import math
import transformers as tfs
from tqdm import notebook
from tqdm import tqdm

from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, ParameterGrid, StratifiedKFold, GridSearchCV
from sklearn.metrics import mean_squared_error, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
import optuna

from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
from torch import cuda
device = t.device("cuda")

# %%
# Зафиксируем random seed
random.seed(0)
np.random.seed(0)
t.manual_seed(0)
t.cuda.manual_seed(0)

# %% [markdown]
# ## 1. Подготовка

# %% [markdown]
# ### 1.1 Загрузим данные

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/toxic_comments.csv', index_col=0)
data.head()
# Out:
#                                                 text  toxic
# 0  Explanation\nWhy the edits made under my usern...      0
# 1  D'aww! He matches this background colour I'm s...      0
# 2  Hey man, I'm really not trying to edit war. It...      0
# 3  "\nMore\nI can't make any real suggestions on ...      0
# 4  You, sir, are my hero. Any chance you remember...      0

# %%
# Посмотрим информацию о датасете
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159292 entries, 0 to 159450
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    159292 non-null  object
#  1   toxic   159292 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.6+ MB

# %%
# Посмотрим на соотношение классов
data['toxic'].value_counts()
# Out:
# 0    143106
# 1     16186
# Name: toxic, dtype: int64

# %% [markdown]
# Классы несбалансированы.

# %% [markdown]
# ### 1.2 Произведем токенизацию и превращение предложений в эмбеддинги при помощи BERT

# %%
tokenizer = tfs.DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = tfs.DistilBertModel.from_pretrained('distilbert-base-uncased')
model.to(device)

# %%
tokenized = data['text'].apply(lambda x: tokenizer.encode(x, add_special_tokens=True, truncation=True))

max_len = 0
for i in tokenized.values:
  if len(i) > max_len:
    max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])

attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape
# Out:
# (159292, 512)

# %%
### Эта ячейка предназначена для сохранения и загрузки промежуточных результатов ###

# with open('/content/drive/MyDrive/Colab Notebooks/padded.pkl', 'wb') as f:
#             pickle.dump(padded, f)

# with open('/content/drive/MyDrive/Colab Notebooks/attention_mask.pkl', 'wb') as f:
#             pickle.dump(attention_mask, f)

# padded = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/padded.pkl', 'rb'))
# attention_mask = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/attention_mask.pkl', 'rb'))

# %%
input_ids = t.tensor(padded).to(device)
attention_mask = t.tensor(attention_mask).to(device)

# %%
batch_size = 100
embeddings = []

for i in notebook.tqdm(range(input_ids.shape[0] // batch_size + 1)):
        batch = input_ids[batch_size*i:batch_size*(i+1)]
        attention_mask_batch = attention_mask[batch_size*i:batch_size*(i+1)]
        
        with t.no_grad():
            batch_embeddings = model(batch, attention_mask=attention_mask_batch)
        
        embeddings.append(batch_embeddings[0][:,0,:].cpu().numpy())
        t.cuda.empty_cache()

features = np.concatenate(embeddings)
features.shape
# Out:
# (159292, 768)

# %%
### Эта ячейка предназначена для сохранения и загрузки промежуточных результатов ###

# with open('/content/drive/MyDrive/Colab Notebooks/features.pkl', 'wb') as f:
#             pickle.dump(features, f)
# features = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/features.pkl', 'rb'))

# %% [markdown]
# ### 1.3 Разделим данные на тренировочную и тестовую выборку.

# %%
train_X, test_X, train_y, test_y = train_test_split(features, data['toxic'].values, test_size=0.1, stratify=data['toxic'], random_state=0)

print('Размер получившихся выборок:')
[print(n, d.shape) for n, d in zip(['train_X', 'test_X', 'train_y', 'test_y'], [train_X, test_X, train_y, test_y])]
print('-'*10)
print('Соотношение классов:')
[print(n, d.value_counts(normalize=True), '\n') for n, d in zip(['train_y\n', 'test_y\n'], [pd.Series(train_y), pd.Series(test_y)])]
# Out:
# Размер получившихся выборок:
# train_X (143362, 768)
# test_X (15930, 768)
# train_y (143362,)
# test_y (15930,)
# ----------
# Соотношение классов:
# train_y
#  0    0.89839
# 1    0.10161
# dtype: float64
#
# test_y
#  0    0.898368
# 1    0.101632
# dtype: float64
# [None, None]

# %%
train_X_short, val_X, train_y_short, val_y = train_test_split(train_X, train_y, test_size=0.1, stratify=train_y, random_state=0)

print('Размер получившихся выборок:')
[print(n, d.shape) for n, d in zip(['train_X_short', 'val_X', 'train_y_short', 'val_y'], [train_X_short, val_X, train_y_short, val_y])]
print('-'*10)
print('Соотношение классов:')
[print(n, d.value_counts(normalize=True), '\n') for n, d in zip(['train_y_short\n', 'val_y\n'], [pd.Series(train_y_short), pd.Series(val_y)])]
# Out:
# Размер получившихся выборок:
# train_X_short (129025, 768)
# val_X (14337, 768)
# train_y_short (129025,)
# val_y (14337,)
# ----------
# Соотношение классов:
# train_y_short
#  0    0.898392
# 1    0.101608
# dtype: float64
#
# val_y
#  0    0.898375
# 1    0.101625
# dtype: float64
# [None, None]

# %%
# Класс для создания датасета
class CustomDataset(Dataset):
  def __init__(self, data, labels):
    self.labels = labels
    self.data = data
    
  def __len__(self):
    return len(self.labels)

  def __getitem__(self, idx):
    label = self.labels[idx]
    data = self.data[idx]
    sample = {"data": data, "labels": label}
    return sample

# %%
# Создаем датасеты
dataset_train = CustomDataset(t.FloatTensor(train_X_short), t.FloatTensor(train_y_short))
dataset_valid = CustomDataset(t.FloatTensor(val_X), t.FloatTensor(val_y))
dataset_test = CustomDataset(t.FloatTensor(test_X), t.FloatTensor(test_y))

# %% [markdown]
# ## 2. Обучение

# %% [markdown]
# ### 2.1 Модель логистической регрессии

# %%
lr = LogisticRegression(random_state=0)
lr_cv_score = cross_val_score(lr, train_X, train_y, scoring='f1', cv=10, error_score='raise')

# %%
print(f"Logistic Regression F1 MEAN {lr_cv_score.mean()}")
print(f"Logistic Regression F1 STD {lr_cv_score.std()}")
# Out:
# Logistic Regression F1 MEAN 0.7421843352358327
# Logistic Regression F1 STD 0.006768508313833861

# %% [markdown]
# P.S. Class-weight показывает качество хуже

# %% [markdown]
# ### 2.2 Модель случайного леса

# %%
rf = RandomForestClassifier(random_state=0)
rf_cv_score = cross_val_score(rf, train_X, train_y, scoring='f1', cv=10, error_score='raise')

# %%
print(f"Random Forest F1 MEAN {rf_cv_score.mean()}")
print(f"Random Forest F1 STD {rf_cv_score.std()}")
# Out:
# Random Forest F1 MEAN 0.6007717571330489
# Random Forest F1 STD 0.008720879041619677

# %% [markdown]
# ### 2.3 Модель градиентного бустинга

# %%
cb = CatBoostClassifier(verbose=False)
cb_cv_score = cross_val_score(cb, train_X, train_y, scoring='f1', cv=10, error_score='raise')

# %%
print(f"CatBoost F1 MEAN {cb_cv_score.mean()}")
print(f"CatBoost F1 STD {cb_cv_score.std()}")
# Out:
# CatBoost F1 MEAN 0.7259454956233083
# CatBoost F1 STD 0.006584851944233039

# %% [markdown]
# ### 2.4 Нейронная сеть

# %% [markdown]
# Оценим результат работы нейронной сети на кросс-валидации.

# %%
# Класс для создания модели нейронной сети
class Perceptron(t.nn.Module):
  @property
  def device(self):
      for p in self.parameters():
          return p.device

  def __init__(self, input_dim=768, num_layers=0, 
                hidden_dim=64, activation=t.nn.ReLU(), output_dim=2, p=0.0):
      super(Perceptron, self).__init__()
      
      self.layers = t.nn.Sequential()
      self.output_dim = output_dim
      
      prev_size = input_dim
      for i in range(num_layers):
          if i >= 1:
              self.layers.add_module(f'relu{i}', activation)
              self.layers.add_module(f'dropout{i}', t.nn.Dropout(p=p))
          if i+1 != num_layers:
              self.layers.add_module(f'layer{i}', 
                                    t.nn.Linear(prev_size, hidden_dim))
              self.layers.add_module(f'batchnorm{i}', 
                                    t.nn.BatchNorm1d(hidden_dim))
          else:
              self.layers.add_module(f'layer{i}', 
                                    t.nn.Linear(prev_size, output_dim))
              self.layers.add_module(f'batchnorm{i}', 
                                    t.nn.BatchNorm1d(output_dim))  
          prev_size = hidden_dim

      if output_dim == 1:
          self.layers.add_module('classifier', 
                                t.nn.Sigmoid())
      elif output_dim == 2:
          self.layers.add_module('classifier', 
                                t.nn.Softmax(dim=1))

  def forward(self, input):
      output = self.layers(input)
      if self.output_dim == 1:
          return output
      elif self.output_dim == 2:
          return output[:, 1]

# Функция для инициализации весов
def init_weights(layer):
    if type(layer) == t.nn.Linear: # Проверка, что слой – полносвязный
        t.nn.init.xavier_normal_(layer.weight)

# %%
# Класс для ранней остановки в ходе обучения модели
class CustomEarlyStopping():
    """
    Ранняя остановка, чтобы остановить тренировку, когда потеря не улучшается после определенной эпохи.
    """
    def __init__(self, patience=10, min_delta=0.5):
        """
        :param patience: сколько эпох ждать, прежде чем остановиться, когда потеря не улучшается
        :param min_delta: минимальная разница между f1-метриками, если улучшений нет, то остановим обучение
        """
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_metric = None
        self.early_stop = False

    def __call__(self, val_metric):
        if self.best_metric == None:
            self.best_metric = val_metric
        elif val_metric - self.best_metric > self.min_delta:
            self.best_metric = val_metric
            # reset counter if validation loss improves
            self.counter = 0
        elif val_metric - self.best_metric < self.min_delta:
            self.counter += 1
            print(f"INFO: Early stopping counter {self.counter} of {self.patience}")
            if self.counter >= self.patience:
                print('INFO: Early stopping')
                self.early_stop = True

# %%
# Функция для обучения модели
def trainer(model, datasettrain, datasetvalid, loss_function, optimizer, 
            epochs, check_val_metric, patience, min_delta, batch_size=64):

  model.cuda()
  early_stopping = CustomEarlyStopping(patience=patience, min_delta=min_delta)

  val_X = datasetvalid.data
  val_y = datasetvalid.labels
  train_dataloader = DataLoader(datasettrain, batch_size=batch_size, shuffle=True, drop_last=True)
  
  # Обучаем модель заданное количество эпох
  for epoch in notebook.tqdm(range(epochs)):
    for batch in train_dataloader:
      batch_X = batch['data'].cuda()
      batch_y = batch['temp'].cuda()

      optimizer.zero_grad()

      predictions = model.forward(batch_X).flatten()
      train_loss = loss_function(predictions, batch_y)

      train_loss.backward()
      optimizer.step()

    # Проверяем качество на валидационной выборке
    model.eval()
    val_pred = model.forward(val_X.cuda()).flatten()
    f1 = f1_score(val_y.cpu().numpy().astype('int'), (val_pred.detach().cpu().numpy() > 0.5).astype('int'))

    early_stopping(f1)
    if early_stopping.early_stop:
      print('Early Stoppning!!!')
      break

    # Выводим метрики на экран каждые "check_val_metric" эпох
    if check_val_metric != 0 and (epoch % check_val_metric == 0 or epoch == epochs - 1):
      print(epoch)
      print('train_loss=', train_loss.cpu().detach().numpy()) 
      print('test_F1=', f1)

    t.cuda.empty_cache()  

# Функция для тестировани модели
def testing(model, dataset):
  test_X = dataset.data
  test_y = dataset.labels

  predictions = model.forward(test_X.cuda()).flatten()
  f1 = f1_score(test_y.cpu().numpy().astype('int'), (predictions.detach().cpu().numpy() > 0.5).astype('int'))

  return f1, classification_report(test_y.cpu().numpy().astype('int'), (predictions.detach().cpu().numpy() > 0.5).astype('int'))

# %%
# Функция для обучения модели без батчей
def trainer_nobatch(model, datasettrain, datasetvalid, loss_function, optimizer, 
                    epochs, check_val_metric, patience, min_delta):

  model.cuda()
  early_stopping = CustomEarlyStopping(patience=patience, min_delta=min_delta)

  val_X = datasetvalid.data
  val_y = datasetvalid.labels

  train_X = datasettrain.data.cuda()
  train_y = datasettrain.labels.cuda()
  
  # Обучаем модель заданное количество эпох
  for epoch in notebook.tqdm(range(epochs)):
    optimizer.zero_grad()

    predictions = model.forward(train_X).flatten()
    train_loss = loss_function(predictions, train_y)

    train_loss.backward()
    optimizer.step()

    # Проверяем качество на валидационной выборке
    model.eval()
    val_pred = model.forward(val_X.cuda()).flatten()
    f1 = f1_score(val_y.cpu().numpy().astype('int'), (val_pred.detach().cpu().numpy() > 0.5).astype('int'))

    early_stopping(f1)
    if early_stopping.early_stop:
      print('Early Stoppning!!!')
      break

    # Выводим метрики на экран каждые "check_val_metric" эпох
    if check_val_metric != 0 and (epoch % check_val_metric == 0 or epoch == epochs - 1):
      print(epoch)
      print('train_loss=', train_loss.cpu().detach().numpy()) 
      print('test_F1=', f1)

    t.cuda.empty_cache()

# %%
# Функция для кросс-валидации нейронной сети
def cross_validate(model, datasettrain, datasetvalid, cv, epochs=100, check_val_metric=1, learning_rate=1e-4, patience=10, min_delta=0.002, batch_size=64):
  skf = StratifiedKFold(cv, random_state=0, shuffle=True)
  number_of_batch = skf.get_n_splits(datasettrain.data, datasettrain.labels)

  list_of_scores = []
  for train_index, test_index in notebook.tqdm(skf.split(datasettrain.data, datasettrain.labels), 
                                               total=number_of_batch):
    train_X_fold = datasettrain.data[train_index]
    train_y_fold = datasettrain.labels[train_index]
    test_X_fold = datasettrain.data[test_index]
    test_y_fold = datasettrain.labels[test_index]
    
    train_dataset_fold = CustomDataset(train_X_fold, train_y_fold)
    test_dataset_fold = CustomDataset(test_X_fold, test_y_fold)
    
    model_fold = model
    model_fold.apply(init_weights)

    model_fold.train()
    trainer(model=model_fold, 
            datasettrain=train_dataset_fold, 
            datasetvalid=datasetvalid, 
            loss_function=t.nn.BCELoss(), 
            optimizer=t.optim.Adam(model_fold.parameters(), lr=learning_rate), 
            epochs=epochs, 
            check_val_metric=check_val_metric, 
            patience=patience,
            min_delta=min_delta, 
            batch_size=batch_size)
    
    model_fold.eval()
    f1, _ = testing(model_fold, test_dataset_fold)
    list_of_scores.append(f1)
    
  return list_of_scores

# %%
# Функция для кросс-валидации нейронной сети без батчей
def cross_validate_nobatch(model, datasettrain, datasetvalid, cv, epochs=100, check_val_metric=1, learning_rate=1e-4, patience=10, min_delta=0.002):
  skf = StratifiedKFold(cv, random_state=0, shuffle=True)
  number_of_batch = skf.get_n_splits(datasettrain.data, datasettrain.labels)

  list_of_scores = []
  for train_index, test_index in notebook.tqdm(skf.split(datasettrain.data, datasettrain.labels), 
                                               total=number_of_batch):
    train_X_fold = datasettrain.data[train_index]
    train_y_fold = datasettrain.labels[train_index]
    test_X_fold = datasettrain.data[test_index]
    test_y_fold = datasettrain.labels[test_index]
    
    train_dataset_fold = CustomDataset(train_X_fold, train_y_fold)
    test_dataset_fold = CustomDataset(test_X_fold, test_y_fold)
    
    model_fold = model
    model_fold.apply(init_weights)

    model_fold.train()
    trainer_nobatch(model=model_fold, 
                    datasettrain=train_dataset_fold, 
                    datasetvalid=datasetvalid, 
                    loss_function=t.nn.BCELoss(), 
                    optimizer=t.optim.Adam(model_fold.parameters(), lr=learning_rate), 
                    epochs=epochs, 
                    check_val_metric=check_val_metric, 
                    patience=patience,
                    min_delta=min_delta)
    
    model_fold.eval()
    f1, _ = testing(model_fold, test_dataset_fold)
    list_of_scores.append(f1)
    
  return list_of_scores

# %% [markdown]
# Получим результаты кросс-валидации для нейронной сети.

# %%
nn_cv_score = cross_validate(model=Perceptron(input_dim=768, 
                                              num_layers=10, 
                                              hidden_dim=256, 
                                              output_dim=1, 
                                              p=0.0),
                             datasettrain=dataset_train, 
                             datasetvalid=dataset_valid, 
                             cv=10)

# %%
print(f"NeuralNet F1 MEAN {np.mean(nn_cv_score)}")
print(f"NeuralNet F1 STD {np.std(nn_cv_score)}")
# Out:
# NeuralNet F1 MEAN 0.7317718127224702
# NeuralNet F1 STD 0.012598051881490803

# %% [markdown]
# Посмотрим также на качество модели, обученной без батчей.

# %%
nn_cv_score_nobatch = cross_validate_nobatch(model=Perceptron(input_dim=768, 
                                                              num_layers=10, 
                                                              hidden_dim=256, 
                                                              output_dim=1, 
                                                              p=0.0),
                                             datasettrain=dataset_train, 
                                             datasetvalid=dataset_valid, 
                                             cv=10,
                                             patience=150, 
                                             epochs=1000, 
                                             check_val_metric=1, 
                                             learning_rate=1e-4, 
                                             min_delta=0.002)

# %%
print(f"NeuralNet #nobatch F1 MEAN {np.mean(nn_cv_score_nobatch)}")
print(f"NeuralNet #nobatch F1 STD {np.std(nn_cv_score_nobatch)}")
# Out:
# NeuralNet #nobatch F1 MEAN 0.7242791469557217
# NeuralNet #nobatch F1 STD 0.02025568477783922

# %% [markdown]
# ### 2.5 Резюме

# %% [markdown]
# На данном этапе мы проверили качество четырех моделей на 10-fold кросс-валидации. Были получены следующие результаты:
#
# |Модель|F1 mean |F1 std|
# |-----|-----|-----|
# |LogisticRegression|0.742|0.007|
# |RandomForest|0.6|0.009|
# |CatBoost| 0.726|0.007|
# |NeuralNet|0.732|0.01|
# |NeuralNet #nobatch|0.724|0.02|
#
# Следующим шагом подберем гиперпараметры для модели нейронной сети и попробуем улучшить ее результат.

# %% [markdown]
# ## 3. Подбор гиперпараметров

# %% [markdown]
# Для подбора гиперпараметров используем библиотеку Optuna.
# Для ускорения поиска гиперпараметров используем 3-fold кросс-валидацию вместо 10-fold.

# %%
def objective(trial):
    
    # Dropout
    p_suggested = trial.suggest_float('p', 0.0, 0.7, step=0.1) 
    
    # Activation
    activation_dict = {"nn.LeakyReLU()": t.nn.LeakyReLU(),
                       "nn.ReLU()": t.nn.ReLU(),
                       "nn.ELU()": t.nn.ELU()
                      }
    activation_suggested = trial.suggest_categorical('activation', ["nn.LeakyReLU()", "nn.ReLU()", "nn.ELU()"])
    activation_suggested = activation_dict.get(activation_suggested)
  
    # Number of hidden layers
    num_layers_suggested = trial.suggest_int('num_layers', 5, 50,  step=5)

    # Number of neurons in hidden dimensions
    hidden_dim_suggested = trial.suggest_int('hidden_dim', 64, 512,  step=64)
    
    # Learning rate
    lr_suggested = trial.suggest_loguniform('learning_rate', 1e-6, 1e-0)
    
    # Batch size 
    batch_size_suggested = trial.suggest_int('batch_size', 64, 1024,  step=64)
    
    # Patience
    patience_suggested = trial.suggest_int('patience', 10, 30,  step=5)
    
    f1_scores = cross_validate(model=Perceptron(input_dim=768, 
                                               num_layers=num_layers_suggested, 
                                               hidden_dim=hidden_dim_suggested, 
                                               activation=activation_suggested,
                                               output_dim=1, 
                                               p=p_suggested), 
                              datasettrain=dataset_train, 
                              datasetvalid=dataset_valid, 
                              cv=3,
                              epochs=500,
                              check_val_metric=1,
                              learning_rate=lr_suggested, 
                              patience=patience_suggested,
                              min_delta=0.002,
                              batch_size=batch_size_suggested)

    return np.mean(f1_scores)

# %%
# %%time
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, timeout=18000)

# %%
# Посмотрим на наилучшее качество на 3-fold кросс-валидации
study.best_trial.values
# Out:
# [0.753203744456273]

# %%
# Посмотрим на подобранные гиперпараметры
best_params = study.best_trial.params
best_params
# Out:
# {'p': 0.5,
#  'activation': 'nn.ELU()',
#  'num_layers': 5,
#  'hidden_dim': 320,
#  'learning_rate': 1.670426452626111e-05,
#  'batch_size': 1024,
#  'patience': 25}

# %%
activation_dict = {
    "nn.LeakyReLU()": t.nn.LeakyReLU(),
    "nn.ReLU()": t.nn.ReLU(),
    "nn.ELU()": t.nn.ELU()
}

# %% [markdown]
# Посмотрим также какое качество покажет модель с подобранными гиперпараметрами на 10-fold кросс-валидации.

# %%
f1_scores = cross_validate(model=Perceptron(input_dim=768, 
                                            num_layers=best_params['num_layers'], 
                                            hidden_dim=best_params['hidden_dim'], 
                                            activation=activation_dict[best_params['activation']],
                                            output_dim=1, 
                                            p=best_params['p']), 
                          datasettrain=dataset_train, 
                          datasetvalid=dataset_valid, 
                          cv=10,
                          epochs=500,
                          check_val_metric=1,
                          learning_rate=best_params['learning_rate'], 
                          patience=best_params['patience'],
                          min_delta=0.002,
                          batch_size=best_params['batch_size'])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.6995009
# test_F1= 0.3286689025095409
# 1
# train_loss= 0.1617064
# test_F1= 0.6214099216710184
# 2
# train_loss= 0.15001813
# test_F1= 0.6904761904761906
# 3
# train_loss= 0.1458354
# test_F1= 0.7103393843725336
# 4
# train_loss= 0.13430719
# test_F1= 0.7232277526395173
# INFO: Early stopping counter 1 of 25
# 5
# train_loss= 0.12601247
# test_F1= 0.7207843137254902
# INFO: Early stopping counter 2 of 25
# 6
# train_loss= 0.11101131
# test_F1= 0.7228537828302627
# 7
# train_loss= 0.15160483
# test_F1= 0.731614859742229
# INFO: Early stopping counter 1 of 25
# 8
# train_loss= 0.14748804
# test_F1= 0.7293754818812643
# INFO: Early stopping counter 2 of 25
# 9
# train_loss= 0.12900734
# test_F1= 0.7294573643410852
# INFO: Early stopping counter 3 of 25
# 10
# train_loss= 0.1450806
# test_F1= 0.7317817626859977
# INFO: Early stopping counter 4 of 25
# 11
# train_loss= 0.15319067
# test_F1= 0.7332038834951458
# INFO: Early stopping counter 5 of 25
# 12
# train_loss= 0.12120539
# test_F1= 0.7309205350118017
# INFO: Early stopping counter 6 of 25
# 13
# train_loss= 0.117941126
# test_F1= 0.7309048178613395
# 14
# train_loss= 0.1402944
# test_F1= 0.7451851851851853
# INFO: Early stopping counter 1 of 25
# 15
# train_loss= 0.107201084
# test_F1= 0.7341870391928599
# INFO: Early stopping counter 2 of 25
# 16
# train_loss= 0.1362599
# test_F1= 0.7372518489684703
# INFO: Early stopping counter 3 of 25
# 17
# train_loss= 0.11685853
# test_F1= 0.7392134402443681
# INFO: Early stopping counter 4 of 25
# 18
# train_loss= 0.11325602
# test_F1= 0.7433831990794015
# INFO: Early stopping counter 5 of 25
# 19
# train_loss= 0.13998976
# test_F1= 0.7454819277108433
# 20
# train_loss= 0.16093042
# test_F1= 0.7484848484848485
# INFO: Early stopping counter 1 of 25
# 21
# train_loss= 0.14829418
# test_F1= 0.7485779294653014
# 22
# train_loss= 0.13371603
# test_F1= 0.752711496746204
# INFO: Early stopping counter 1 of 25
# 23
# train_loss= 0.14261454
# test_F1= 0.7491435097068899
# INFO: Early stopping counter 2 of 25
# 24
# train_loss= 0.11743993
# test_F1= 0.746062235881675
# INFO: Early stopping counter 3 of 25
# 25
# train_loss= 0.100869514
# test_F1= 0.7538519353626457
# INFO: Early stopping counter 4 of 25
# 26
# train_loss= 0.13085705
# test_F1= 0.7467382962394475
# INFO: Early stopping counter 5 of 25
# 27
# train_loss= 0.11056755
# test_F1= 0.7501881113619262
# INFO: Early stopping counter 6 of 25
# 28
# train_loss= 0.11639123
# test_F1= 0.7544457056375331
# INFO: Early stopping counter 7 of 25
# 29
# train_loss= 0.12110166
# test_F1= 0.7544322897019992
# INFO: Early stopping counter 8 of 25
# 30
# train_loss= 0.11261917
# test_F1= 0.7538752362948961
# INFO: Early stopping counter 9 of 25
# 31
# train_loss= 0.12242536
# test_F1= 0.7540983606557377
# INFO: Early stopping counter 10 of 25
# 32
# train_loss= 0.10035759
# test_F1= 0.7527788424683787
# 33
# train_loss= 0.11857565
# test_F1= 0.7597930524759795
# INFO: Early stopping counter 1 of 25
# 34
# train_loss= 0.095909074
# test_F1= 0.7558095238095238
# INFO: Early stopping counter 2 of 25
# 35
# train_loss= 0.11567933
# test_F1= 0.7510613662678503
# INFO: Early stopping counter 3 of 25
# 36
# train_loss= 0.11986462
# test_F1= 0.7567567567567567
# INFO: Early stopping counter 4 of 25
# 37
# train_loss= 0.10638097
# test_F1= 0.7542988154375238
# INFO: Early stopping counter 5 of 25
# 38
# train_loss= 0.1183376
# test_F1= 0.7499033629686896
# INFO: Early stopping counter 6 of 25
# 39
# train_loss= 0.11717478
# test_F1= 0.7443315089913994
# INFO: Early stopping counter 7 of 25
# 40
# train_loss= 0.10707398
# test_F1= 0.7609351432880845
# INFO: Early stopping counter 8 of 25
# 41
# train_loss= 0.112322606
# test_F1= 0.7306451612903224
# INFO: Early stopping counter 9 of 25
# 42
# train_loss= 0.07785155
# test_F1= 0.760436254230914
# 43
# train_loss= 0.1329211
# test_F1= 0.7637588918008236
# 44
# train_loss= 0.112983145
# test_F1= 0.7658019729630983
# INFO: Early stopping counter 1 of 25
# 45
# train_loss= 0.11686726
# test_F1= 0.7664670658682634
# INFO: Early stopping counter 2 of 25
# 46
# train_loss= 0.097840026
# test_F1= 0.7542503863987635
# 47
# train_loss= 0.11986136
# test_F1= 0.7714808043875686
# INFO: Early stopping counter 1 of 25
# 48
# train_loss= 0.096933395
# test_F1= 0.7679231337767923
# INFO: Early stopping counter 2 of 25
# 49
# train_loss= 0.12626682
# test_F1= 0.7626546681664792
# INFO: Early stopping counter 3 of 25
# 50
# train_loss= 0.11926304
# test_F1= 0.7690623859905144
# INFO: Early stopping counter 4 of 25
# 51
# train_loss= 0.09739882
# test_F1= 0.7678244972577696
# INFO: Early stopping counter 5 of 25
# 52
# train_loss= 0.09926697
# test_F1= 0.7533980582524272
# INFO: Early stopping counter 6 of 25
# 53
# train_loss= 0.08936151
# test_F1= 0.7691160014919807
# INFO: Early stopping counter 7 of 25
# 54
# train_loss= 0.1322176
# test_F1= 0.7667540247098465
# INFO: Early stopping counter 8 of 25
# 55
# train_loss= 0.09077953
# test_F1= 0.7596664139499621
# INFO: Early stopping counter 9 of 25
# 56
# train_loss= 0.10095703
# test_F1= 0.7604126862820022
# INFO: Early stopping counter 10 of 25
# 57
# train_loss= 0.108720094
# test_F1= 0.7679702048417132
# INFO: Early stopping counter 11 of 25
# 58
# train_loss= 0.15300563
# test_F1= 0.7556752597152752
# INFO: Early stopping counter 12 of 25
# 59
# train_loss= 0.112674505
# test_F1= 0.7603053435114504
# INFO: Early stopping counter 13 of 25
# 60
# train_loss= 0.108322464
# test_F1= 0.7617969044922611
# INFO: Early stopping counter 14 of 25
# 61
# train_loss= 0.08835791
# test_F1= 0.7632270168855535
# INFO: Early stopping counter 15 of 25
# 62
# train_loss= 0.10562666
# test_F1= 0.7703541438481197
# INFO: Early stopping counter 16 of 25
# 63
# train_loss= 0.10248159
# test_F1= 0.7691773689691079
# INFO: Early stopping counter 17 of 25
# 64
# train_loss= 0.10345318
# test_F1= 0.7672155688622754
# INFO: Early stopping counter 18 of 25
# 65
# train_loss= 0.1000302
# test_F1= 0.763010108573568
# INFO: Early stopping counter 19 of 25
# 66
# train_loss= 0.123987585
# test_F1= 0.7719424460431654
# INFO: Early stopping counter 20 of 25
# 67
# train_loss= 0.122764334
# test_F1= 0.7502940023520188
# INFO: Early stopping counter 21 of 25
# 68
# train_loss= 0.08986269
# test_F1= 0.7728440366972478
# INFO: Early stopping counter 22 of 25
# 69
# train_loss= 0.11373076
# test_F1= 0.7708716439867599
# INFO: Early stopping counter 23 of 25
# 70
# train_loss= 0.08607549
# test_F1= 0.7660967624590761
# INFO: Early stopping counter 24 of 25
# 71
# train_loss= 0.14270264
# test_F1= 0.7716994894237783
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.706788
# test_F1= 0.32809773123909247
# 1
# train_loss= 0.16735536
# test_F1= 0.6151843817787419
# 2
# train_loss= 0.16895813
# test_F1= 0.6761019005256773
# 3
# train_loss= 0.14413103
# test_F1= 0.6989289964299881
# 4
# train_loss= 0.14710203
# test_F1= 0.711651628089447
# 5
# train_loss= 0.14144102
# test_F1= 0.7245600612088753
# INFO: Early stopping counter 1 of 25
# 6
# train_loss= 0.12433989
# test_F1= 0.7159225602528645
# 7
# train_loss= 0.12428923
# test_F1= 0.7290076335877862
# INFO: Early stopping counter 1 of 25
# 8
# train_loss= 0.13776079
# test_F1= 0.7286643704554152
# INFO: Early stopping counter 2 of 25
# 9
# train_loss= 0.124412954
# test_F1= 0.7272727272727273
# 10
# train_loss= 0.12838155
# test_F1= 0.7451708766716196
# INFO: Early stopping counter 1 of 25
# 11
# train_loss= 0.13621292
# test_F1= 0.7321221492075763
# INFO: Early stopping counter 2 of 25
# 12
# train_loss= 0.13881432
# test_F1= 0.7377609108159393
# INFO: Early stopping counter 3 of 25
# 13
# train_loss= 0.12487112
# test_F1= 0.7395793499043977
# 14
# train_loss= 0.12669139
# test_F1= 0.7474074074074074
# INFO: Early stopping counter 1 of 25
# 15
# train_loss= 0.103451
# test_F1= 0.7448902346707039
# INFO: Early stopping counter 2 of 25
# 16
# train_loss= 0.11820153
# test_F1= 0.747908330301928
# INFO: Early stopping counter 3 of 25
# 17
# train_loss= 0.14623511
# test_F1= 0.7467876039304611
# INFO: Early stopping counter 4 of 25
# 18
# train_loss= 0.13223629
# test_F1= 0.7476085356880059
# INFO: Early stopping counter 5 of 25
# 19
# train_loss= 0.119253725
# test_F1= 0.731572723689397
# INFO: Early stopping counter 6 of 25
# 20
# train_loss= 0.09939494
# test_F1= 0.7482594356907293
# INFO: Early stopping counter 7 of 25
# 21
# train_loss= 0.12205464
# test_F1= 0.7472775065715359
# 22
# train_loss= 0.097386904
# test_F1= 0.7499056959637872
# INFO: Early stopping counter 1 of 25
# 23
# train_loss= 0.12169395
# test_F1= 0.7504501260352898
# 24
# train_loss= 0.13629892
# test_F1= 0.7519523986612123
# INFO: Early stopping counter 1 of 25
# 25
# train_loss= 0.116294146
# test_F1= 0.7492514970059879
# INFO: Early stopping counter 2 of 25
# 26
# train_loss= 0.11663916
# test_F1= 0.7428571428571428
# INFO: Early stopping counter 3 of 25
# 27
# train_loss= 0.102083445
# test_F1= 0.7515971439308531
# INFO: Early stopping counter 4 of 25
# 28
# train_loss= 0.1228825
# test_F1= 0.7521304186735828
# 29
# train_loss= 0.11491212
# test_F1= 0.7557395558901017
# INFO: Early stopping counter 1 of 25
# 30
# train_loss= 0.12538517
# test_F1= 0.7523487410747839
# INFO: Early stopping counter 2 of 25
# 31
# train_loss= 0.12247564
# test_F1= 0.7527922561429635
# INFO: Early stopping counter 3 of 25
# 32
# train_loss= 0.109614804
# test_F1= 0.7565377532228361
# INFO: Early stopping counter 4 of 25
# 33
# train_loss= 0.086642504
# test_F1= 0.7473118279569892
# INFO: Early stopping counter 5 of 25
# 34
# train_loss= 0.099797584
# test_F1= 0.7547864506627393
# INFO: Early stopping counter 6 of 25
# 35
# train_loss= 0.113541536
# test_F1= 0.7510484178421655
# INFO: Early stopping counter 7 of 25
# 36
# train_loss= 0.10494809
# test_F1= 0.7530211480362538
# 37
# train_loss= 0.1211525
# test_F1= 0.7643904183053272
# INFO: Early stopping counter 1 of 25
# 38
# train_loss= 0.10156555
# test_F1= 0.7588730332967435
# INFO: Early stopping counter 2 of 25
# 39
# train_loss= 0.108564295
# test_F1= 0.7438735177865612
# INFO: Early stopping counter 3 of 25
# 40
# train_loss= 0.1235684
# test_F1= 0.7617302052785924
# INFO: Early stopping counter 4 of 25
# 41
# train_loss= 0.10621524
# test_F1= 0.7549057329742208
# INFO: Early stopping counter 5 of 25
# 42
# train_loss= 0.115246385
# test_F1= 0.761699064074874
# INFO: Early stopping counter 6 of 25
# 43
# train_loss= 0.07777816
# test_F1= 0.7562452687358062
# INFO: Early stopping counter 7 of 25
# 44
# train_loss= 0.109283626
# test_F1= 0.7585185185185185
# INFO: Early stopping counter 8 of 25
# 45
# train_loss= 0.09031062
# test_F1= 0.7571860816944025
# INFO: Early stopping counter 9 of 25
# 46
# train_loss= 0.123940885
# test_F1= 0.7604901596732269
# INFO: Early stopping counter 10 of 25
# 47
# train_loss= 0.11933245
# test_F1= 0.7610619469026549
# INFO: Early stopping counter 11 of 25
# 48
# train_loss= 0.09352524
# test_F1= 0.7584919746173945
# INFO: Early stopping counter 12 of 25
# 49
# train_loss= 0.10157381
# test_F1= 0.7606996650539636
# INFO: Early stopping counter 13 of 25
# 50
# train_loss= 0.080093585
# test_F1= 0.7527703477264044
# INFO: Early stopping counter 14 of 25
# 51
# train_loss= 0.123396754
# test_F1= 0.7630522088353413
# INFO: Early stopping counter 15 of 25
# 52
# train_loss= 0.10760507
# test_F1= 0.7582794061667301
# INFO: Early stopping counter 16 of 25
# 53
# train_loss= 0.10753392
# test_F1= 0.7485515643105446
# INFO: Early stopping counter 17 of 25
# 54
# train_loss= 0.10134109
# test_F1= 0.7584905660377359
# INFO: Early stopping counter 18 of 25
# 55
# train_loss= 0.094389945
# test_F1= 0.7663416395810763
# INFO: Early stopping counter 19 of 25
# 56
# train_loss= 0.12824069
# test_F1= 0.7634885439763489
# INFO: Early stopping counter 20 of 25
# 57
# train_loss= 0.103830494
# test_F1= 0.7555388659406685
# INFO: Early stopping counter 21 of 25
# 58
# train_loss= 0.115844026
# test_F1= 0.7509607993850884
# INFO: Early stopping counter 22 of 25
# 59
# train_loss= 0.08906084
# test_F1= 0.7541106128550075
# INFO: Early stopping counter 23 of 25
# 60
# train_loss= 0.08453418
# test_F1= 0.7543726235741445
# INFO: Early stopping counter 24 of 25
# 61
# train_loss= 0.08539247
# test_F1= 0.7351524879614767
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.6883637
# test_F1= 0.3457668711656442
# 1
# train_loss= 0.19357878
# test_F1= 0.6203904555314533
# 2
# train_loss= 0.15990517
# test_F1= 0.6715806715806716
# 3
# train_loss= 0.13701427
# test_F1= 0.6995622761639475
# 4
# train_loss= 0.123461634
# test_F1= 0.7141732283464567
# 5
# train_loss= 0.14795
# test_F1= 0.7225455956538611
# 6
# train_loss= 0.15086134
# test_F1= 0.7292859870179458
# INFO: Early stopping counter 1 of 25
# 7
# train_loss= 0.14128429
# test_F1= 0.7294388931591085
# INFO: Early stopping counter 2 of 25
# 8
# train_loss= 0.16624671
# test_F1= 0.7303065580131937
# INFO: Early stopping counter 3 of 25
# 9
# train_loss= 0.11469418
# test_F1= 0.730488273740869
# 10
# train_loss= 0.097096115
# test_F1= 0.734108527131783
# INFO: Early stopping counter 1 of 25
# 11
# train_loss= 0.10777195
# test_F1= 0.7235901509134234
# 12
# train_loss= 0.14341542
# test_F1= 0.747961452928095
# INFO: Early stopping counter 1 of 25
# 13
# train_loss= 0.1314959
# test_F1= 0.7284978200554895
# INFO: Early stopping counter 2 of 25
# 14
# train_loss= 0.10483601
# test_F1= 0.7381044487427466
# INFO: Early stopping counter 3 of 25
# 15
# train_loss= 0.1263426
# test_F1= 0.7292817679558012
# 16
# train_loss= 0.12843804
# test_F1= 0.7514970059880238
# INFO: Early stopping counter 1 of 25
# 17
# train_loss= 0.12527694
# test_F1= 0.7359375
# INFO: Early stopping counter 2 of 25
# 18
# train_loss= 0.12785909
# test_F1= 0.7486752460257381
# INFO: Early stopping counter 3 of 25
# 19
# train_loss= 0.10433605
# test_F1= 0.7534646243617796
# 20
# train_loss= 0.10348226
# test_F1= 0.7555057857409482
# INFO: Early stopping counter 1 of 25
# 21
# train_loss= 0.15139477
# test_F1= 0.7401636151149202
# INFO: Early stopping counter 2 of 25
# 22
# train_loss= 0.11421948
# test_F1= 0.7523701175578308
# INFO: Early stopping counter 3 of 25
# 23
# train_loss= 0.116370745
# test_F1= 0.752851711026616
# INFO: Early stopping counter 4 of 25
# 24
# train_loss= 0.1122686
# test_F1= 0.74884437596302
# INFO: Early stopping counter 5 of 25
# 25
# train_loss= 0.11362998
# test_F1= 0.7422924901185771
# INFO: Early stopping counter 6 of 25
# 26
# train_loss= 0.11433021
# test_F1= 0.7351178585697163
# INFO: Early stopping counter 7 of 25
# 27
# train_loss= 0.11611883
# test_F1= 0.7549019607843136
# 28
# train_loss= 0.10085371
# test_F1= 0.7600147004777656
# 29
# train_loss= 0.096811235
# test_F1= 0.7656362329259525
# INFO: Early stopping counter 1 of 25
# 30
# train_loss= 0.12684497
# test_F1= 0.7633813215208564
# INFO: Early stopping counter 2 of 25
# 31
# train_loss= 0.1316645
# test_F1= 0.7494235203689469
# INFO: Early stopping counter 3 of 25
# 32
# train_loss= 0.11044794
# test_F1= 0.7523992322456813
# INFO: Early stopping counter 4 of 25
# 33
# train_loss= 0.119472146
# test_F1= 0.7506764592191728
# INFO: Early stopping counter 5 of 25
# 34
# train_loss= 0.10753226
# test_F1= 0.7659417618872097
# INFO: Early stopping counter 6 of 25
# 35
# train_loss= 0.101185344
# test_F1= 0.7581749049429659
# INFO: Early stopping counter 7 of 25
# 36
# train_loss= 0.113917165
# test_F1= 0.7459882583170255
# INFO: Early stopping counter 8 of 25
# 37
# train_loss= 0.12635806
# test_F1= 0.7346938775510204
# 38
# train_loss= 0.11569476
# test_F1= 0.7716138328530258
# INFO: Early stopping counter 1 of 25
# 39
# train_loss= 0.10524781
# test_F1= 0.7652757078986587
# INFO: Early stopping counter 2 of 25
# 40
# train_loss= 0.11436666
# test_F1= 0.759789156626506
# INFO: Early stopping counter 3 of 25
# 41
# train_loss= 0.12133224
# test_F1= 0.7531865585168019
# INFO: Early stopping counter 4 of 25
# 42
# train_loss= 0.11114194
# test_F1= 0.7696814353716587
# INFO: Early stopping counter 5 of 25
# 43
# train_loss= 0.10239236
# test_F1= 0.7616909839132061
# INFO: Early stopping counter 6 of 25
# 44
# train_loss= 0.10740374
# test_F1= 0.7731884057971015
# INFO: Early stopping counter 7 of 25
# 45
# train_loss= 0.12930799
# test_F1= 0.7706890266131973
# INFO: Early stopping counter 8 of 25
# 46
# train_loss= 0.09410839
# test_F1= 0.7562833206397562
# INFO: Early stopping counter 9 of 25
# 47
# train_loss= 0.113525376
# test_F1= 0.7424539396315171
# INFO: Early stopping counter 10 of 25
# 48
# train_loss= 0.12424749
# test_F1= 0.7648809523809523
# INFO: Early stopping counter 11 of 25
# 49
# train_loss= 0.10118844
# test_F1= 0.758070641853399
# INFO: Early stopping counter 12 of 25
# 50
# train_loss= 0.12599877
# test_F1= 0.7617260787992495
# INFO: Early stopping counter 13 of 25
# 51
# train_loss= 0.1332284
# test_F1= 0.7607223476297967
# INFO: Early stopping counter 14 of 25
# 52
# train_loss= 0.100899324
# test_F1= 0.7726942628903414
# INFO: Early stopping counter 15 of 25
# 53
# train_loss= 0.10538745
# test_F1= 0.7611884166980069
# INFO: Early stopping counter 16 of 25
# 54
# train_loss= 0.10797292
# test_F1= 0.7595031990967257
# 55
# train_loss= 0.11724469
# test_F1= 0.7765726681127983
# INFO: Early stopping counter 1 of 25
# 56
# train_loss= 0.11762529
# test_F1= 0.7573696145124716
# INFO: Early stopping counter 2 of 25
# 57
# train_loss= 0.09582583
# test_F1= 0.7733721353219352
# INFO: Early stopping counter 3 of 25
# 58
# train_loss= 0.11639395
# test_F1= 0.777078965758211
# INFO: Early stopping counter 4 of 25
# 59
# train_loss= 0.116053544
# test_F1= 0.7370091233637445
# 60
# train_loss= 0.10797309
# test_F1= 0.7788495891389783
# INFO: Early stopping counter 1 of 25
# 61
# train_loss= 0.10202478
# test_F1= 0.7691187181354697
# INFO: Early stopping counter 2 of 25
# 62
# train_loss= 0.107958116
# test_F1= 0.7593703148425787
# INFO: Early stopping counter 3 of 25
# 63
# train_loss= 0.10125807
# test_F1= 0.7614747930775018
# INFO: Early stopping counter 4 of 25
# 64
# train_loss= 0.085514985
# test_F1= 0.7463739709917679
# INFO: Early stopping counter 5 of 25
# 65
# train_loss= 0.11888662
# test_F1= 0.7710843373493976
# INFO: Early stopping counter 6 of 25
# 66
# train_loss= 0.09832247
# test_F1= 0.7707567964731815
# INFO: Early stopping counter 7 of 25
# 67
# train_loss= 0.103386
# test_F1= 0.7803325079589672
# INFO: Early stopping counter 8 of 25
# 68
# train_loss= 0.09218049
# test_F1= 0.757598784194529
# INFO: Early stopping counter 9 of 25
# 69
# train_loss= 0.11265073
# test_F1= 0.7592174567343868
# INFO: Early stopping counter 10 of 25
# 70
# train_loss= 0.09149678
# test_F1= 0.7515337423312884
# INFO: Early stopping counter 11 of 25
# 71
# train_loss= 0.1065952
# test_F1= 0.7660208643815201
# INFO: Early stopping counter 12 of 25
# 72
# train_loss= 0.10275403
# test_F1= 0.759742716609913
# INFO: Early stopping counter 13 of 25
# 73
# train_loss= 0.0891748
# test_F1= 0.7676842889054355
# INFO: Early stopping counter 14 of 25
# 74
# train_loss= 0.07515533
# test_F1= 0.7660687593423021
# INFO: Early stopping counter 15 of 25
# 75
# train_loss= 0.09604964
# test_F1= 0.7734604105571848
# INFO: Early stopping counter 16 of 25
# 76
# train_loss= 0.089730695
# test_F1= 0.7652757078986587
# INFO: Early stopping counter 17 of 25
# 77
# train_loss= 0.076657206
# test_F1= 0.7584396099024757
# INFO: Early stopping counter 18 of 25
# 78
# train_loss= 0.0890276
# test_F1= 0.779312787814382
# INFO: Early stopping counter 19 of 25
# 79
# train_loss= 0.10105109
# test_F1= 0.7718023255813953
# INFO: Early stopping counter 20 of 25
# 80
# train_loss= 0.10741338
# test_F1= 0.7537342014553811
# INFO: Early stopping counter 21 of 25
# 81
# train_loss= 0.075053155
# test_F1= 0.7615844544095665
# INFO: Early stopping counter 22 of 25
# 82
# train_loss= 0.08333467
# test_F1= 0.7676317743132887
# INFO: Early stopping counter 23 of 25
# 83
# train_loss= 0.09769869
# test_F1= 0.7713864306784661
# INFO: Early stopping counter 24 of 25
# 84
# train_loss= 0.10067658
# test_F1= 0.7690069116042196
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.6871417
# test_F1= 0.35384421794387816
# 1
# train_loss= 0.161606
# test_F1= 0.6272648835202761
# 2
# train_loss= 0.1461257
# test_F1= 0.6890416498180348
# 3
# train_loss= 0.15843937
# test_F1= 0.7047619047619047
# 4
# train_loss= 0.11029507
# test_F1= 0.7108097327483047
# 5
# train_loss= 0.12903601
# test_F1= 0.717684377478192
# 6
# train_loss= 0.13888407
# test_F1= 0.7260802469135803
# INFO: Early stopping counter 1 of 25
# 7
# train_loss= 0.14845335
# test_F1= 0.7278358497870693
# 8
# train_loss= 0.13761277
# test_F1= 0.7319148936170212
# INFO: Early stopping counter 1 of 25
# 9
# train_loss= 0.1384241
# test_F1= 0.7290524667188724
# 10
# train_loss= 0.17089608
# test_F1= 0.7421991084695394
# INFO: Early stopping counter 1 of 25
# 11
# train_loss= 0.11862131
# test_F1= 0.7213114754098361
# INFO: Early stopping counter 2 of 25
# 12
# train_loss= 0.11808206
# test_F1= 0.7205468435866506
# INFO: Early stopping counter 3 of 25
# 13
# train_loss= 0.14242554
# test_F1= 0.7417268923545073
# INFO: Early stopping counter 4 of 25
# 14
# train_loss= 0.121173054
# test_F1= 0.7350293542074363
# INFO: Early stopping counter 5 of 25
# 15
# train_loss= 0.12740935
# test_F1= 0.7381411492479755
# INFO: Early stopping counter 6 of 25
# 16
# train_loss= 0.121060066
# test_F1= 0.729589804858622
# INFO: Early stopping counter 7 of 25
# 17
# train_loss= 0.12527476
# test_F1= 0.7357392316647263
# 18
# train_loss= 0.11947189
# test_F1= 0.75027912169706
# INFO: Early stopping counter 1 of 25
# 19
# train_loss= 0.11877636
# test_F1= 0.7397047397047396
# INFO: Early stopping counter 2 of 25
# 20
# train_loss= 0.122238755
# test_F1= 0.7469512195121951
# INFO: Early stopping counter 3 of 25
# 21
# train_loss= 0.1100772
# test_F1= 0.7502774694783574
# INFO: Early stopping counter 4 of 25
# 22
# train_loss= 0.12389846
# test_F1= 0.7449768160741885
# INFO: Early stopping counter 5 of 25
# 23
# train_loss= 0.106102005
# test_F1= 0.7469418960244648
# INFO: Early stopping counter 6 of 25
# 24
# train_loss= 0.100746244
# test_F1= 0.7470431133155284
# INFO: Early stopping counter 7 of 25
# 25
# train_loss= 0.09377308
# test_F1= 0.7404817404817406
# INFO: Early stopping counter 8 of 25
# 26
# train_loss= 0.11187911
# test_F1= 0.7399068322981366
# INFO: Early stopping counter 9 of 25
# 27
# train_loss= 0.113192484
# test_F1= 0.7445755614769699
# INFO: Early stopping counter 10 of 25
# 28
# train_loss= 0.13452496
# test_F1= 0.742283950617284
# INFO: Early stopping counter 11 of 25
# 29
# train_loss= 0.10191915
# test_F1= 0.7427466150870408
# INFO: Early stopping counter 12 of 25
# 30
# train_loss= 0.12600833
# test_F1= 0.746996996996997
# INFO: Early stopping counter 13 of 25
# 31
# train_loss= 0.11152387
# test_F1= 0.7508430123641814
# INFO: Early stopping counter 14 of 25
# 32
# train_loss= 0.092084646
# test_F1= 0.7474441499432034
# INFO: Early stopping counter 15 of 25
# 33
# train_loss= 0.1046371
# test_F1= 0.7500000000000001
# INFO: Early stopping counter 16 of 25
# 34
# train_loss= 0.11612874
# test_F1= 0.7455938697318009
# INFO: Early stopping counter 17 of 25
# 35
# train_loss= 0.09826924
# test_F1= 0.7518853695324282
# INFO: Early stopping counter 18 of 25
# 36
# train_loss= 0.105401926
# test_F1= 0.7439353099730457
# 37
# train_loss= 0.12255147
# test_F1= 0.7584699453551913
# INFO: Early stopping counter 1 of 25
# 38
# train_loss= 0.12135038
# test_F1= 0.7554904831625183
# INFO: Early stopping counter 2 of 25
# 39
# train_loss= 0.14703657
# test_F1= 0.7391812865497076
# INFO: Early stopping counter 3 of 25
# 40
# train_loss= 0.10793636
# test_F1= 0.75037147102526
# INFO: Early stopping counter 4 of 25
# 41
# train_loss= 0.11919317
# test_F1= 0.759529747060919
# INFO: Early stopping counter 5 of 25
# 42
# train_loss= 0.11686559
# test_F1= 0.7519759126834776
# INFO: Early stopping counter 6 of 25
# 43
# train_loss= 0.11398375
# test_F1= 0.7455032529659396
# INFO: Early stopping counter 7 of 25
# 44
# train_loss= 0.10280332
# test_F1= 0.7557364914877868
# INFO: Early stopping counter 8 of 25
# 45
# train_loss= 0.10131362
# test_F1= 0.7488514548238897
# INFO: Early stopping counter 9 of 25
# 46
# train_loss= 0.10832344
# test_F1= 0.7599118942731278
# INFO: Early stopping counter 10 of 25
# 47
# train_loss= 0.11683418
# test_F1= 0.7420991026141242
# INFO: Early stopping counter 11 of 25
# 48
# train_loss= 0.09791645
# test_F1= 0.7543461829176115
# INFO: Early stopping counter 12 of 25
# 49
# train_loss= 0.08925858
# test_F1= 0.7423001949317738
# INFO: Early stopping counter 13 of 25
# 50
# train_loss= 0.09392527
# test_F1= 0.7528971962616822
# INFO: Early stopping counter 14 of 25
# 51
# train_loss= 0.11071088
# test_F1= 0.7581360946745561
# INFO: Early stopping counter 15 of 25
# 52
# train_loss= 0.10566981
# test_F1= 0.7536448598130842
# INFO: Early stopping counter 16 of 25
# 53
# train_loss= 0.10998612
# test_F1= 0.749713412304165
# INFO: Early stopping counter 17 of 25
# 54
# train_loss= 0.11560782
# test_F1= 0.7580524344569288
# INFO: Early stopping counter 18 of 25
# 55
# train_loss= 0.12043771
# test_F1= 0.7544457056375331
# INFO: Early stopping counter 19 of 25
# 56
# train_loss= 0.100949466
# test_F1= 0.7562452687358062
# INFO: Early stopping counter 20 of 25
# 57
# train_loss= 0.09265575
# test_F1= 0.740625
# 58
# train_loss= 0.09436459
# test_F1= 0.7637795275590551
# INFO: Early stopping counter 1 of 25
# 59
# train_loss= 0.091583714
# test_F1= 0.7529682114132517
# INFO: Early stopping counter 2 of 25
# 60
# train_loss= 0.10973649
# test_F1= 0.7572598659717051
# INFO: Early stopping counter 3 of 25
# 61
# train_loss= 0.0995654
# test_F1= 0.756333830104322
# INFO: Early stopping counter 4 of 25
# 62
# train_loss= 0.111964405
# test_F1= 0.7578947368421053
# INFO: Early stopping counter 5 of 25
# 63
# train_loss= 0.09469998
# test_F1= 0.7470340604668965
# INFO: Early stopping counter 6 of 25
# 64
# train_loss= 0.11004004
# test_F1= 0.7559055118110236
# INFO: Early stopping counter 7 of 25
# 65
# train_loss= 0.098875836
# test_F1= 0.7545623836126629
# INFO: Early stopping counter 8 of 25
# 66
# train_loss= 0.12734069
# test_F1= 0.757453073242547
# INFO: Early stopping counter 9 of 25
# 67
# train_loss= 0.11384319
# test_F1= 0.7619047619047619
# INFO: Early stopping counter 10 of 25
# 68
# train_loss= 0.10180226
# test_F1= 0.7522727272727272
# INFO: Early stopping counter 11 of 25
# 69
# train_loss= 0.094823375
# test_F1= 0.7541229385307345
# INFO: Early stopping counter 12 of 25
# 70
# train_loss= 0.12794384
# test_F1= 0.746451860375911
# INFO: Early stopping counter 13 of 25
# 71
# train_loss= 0.088126004
# test_F1= 0.7534918837297094
# INFO: Early stopping counter 14 of 25
# 72
# train_loss= 0.102070965
# test_F1= 0.7629310344827586
# INFO: Early stopping counter 15 of 25
# 73
# train_loss= 0.0912457
# test_F1= 0.752808988764045
# INFO: Early stopping counter 16 of 25
# 74
# train_loss= 0.10125095
# test_F1= 0.7551319648093842
# INFO: Early stopping counter 17 of 25
# 75
# train_loss= 0.089444816
# test_F1= 0.7503770739064856
# INFO: Early stopping counter 18 of 25
# 76
# train_loss= 0.10426363
# test_F1= 0.7536231884057972
# INFO: Early stopping counter 19 of 25
# 77
# train_loss= 0.09053694
# test_F1= 0.7437185929648241
# INFO: Early stopping counter 20 of 25
# 78
# train_loss= 0.08874433
# test_F1= 0.754898336414048
# INFO: Early stopping counter 21 of 25
# 79
# train_loss= 0.09079915
# test_F1= 0.7578096288129366
# INFO: Early stopping counter 22 of 25
# 80
# train_loss= 0.11220883
# test_F1= 0.7649373881932022
# INFO: Early stopping counter 23 of 25
# 81
# train_loss= 0.07516116
# test_F1= 0.7494339622641509
# INFO: Early stopping counter 24 of 25
# 82
# train_loss= 0.09034928
# test_F1= 0.7547030616008854
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.6905758
# test_F1= 0.298379508625196
# 1
# train_loss= 0.14887454
# test_F1= 0.6376440460947502
# 2
# train_loss= 0.14073354
# test_F1= 0.686131386861314
# 3
# train_loss= 0.1179664
# test_F1= 0.7052756842522808
# 4
# train_loss= 0.13654682
# test_F1= 0.7193186217576462
# INFO: Early stopping counter 1 of 25
# 5
# train_loss= 0.12671083
# test_F1= 0.7161366313309776
# INFO: Early stopping counter 2 of 25
# 6
# train_loss= 0.120676346
# test_F1= 0.7212857702861623
# 7
# train_loss= 0.11713119
# test_F1= 0.7274137262504847
# 8
# train_loss= 0.1366513
# test_F1= 0.7356760886172651
# INFO: Early stopping counter 1 of 25
# 9
# train_loss= 0.12272801
# test_F1= 0.7286158631415242
# 10
# train_loss= 0.15025967
# test_F1= 0.7426636568848758
# INFO: Early stopping counter 1 of 25
# 11
# train_loss= 0.12562886
# test_F1= 0.728700431880644
# 12
# train_loss= 0.12746382
# test_F1= 0.7450094161958569
# INFO: Early stopping counter 1 of 25
# 13
# train_loss= 0.11852674
# test_F1= 0.7384259259259259
# INFO: Early stopping counter 2 of 25
# 14
# train_loss= 0.1313445
# test_F1= 0.727561556791104
# 15
# train_loss= 0.11315
# test_F1= 0.747391952309985
# INFO: Early stopping counter 1 of 25
# 16
# train_loss= 0.1260735
# test_F1= 0.7309964552973611
# INFO: Early stopping counter 2 of 25
# 17
# train_loss= 0.12357816
# test_F1= 0.7430103408655688
# INFO: Early stopping counter 3 of 25
# 18
# train_loss= 0.13912812
# test_F1= 0.7444359171143515
# INFO: Early stopping counter 4 of 25
# 19
# train_loss= 0.097975954
# test_F1= 0.7493462831527828
# 20
# train_loss= 0.12155627
# test_F1= 0.7518355359765052
# INFO: Early stopping counter 1 of 25
# 21
# train_loss= 0.10907924
# test_F1= 0.7470521110688476
# INFO: Early stopping counter 2 of 25
# 22
# train_loss= 0.11959268
# test_F1= 0.7522658610271904
# INFO: Early stopping counter 3 of 25
# 23
# train_loss= 0.12802899
# test_F1= 0.7486590038314176
# INFO: Early stopping counter 4 of 25
# 24
# train_loss= 0.14033556
# test_F1= 0.7372549019607841
# INFO: Early stopping counter 5 of 25
# 25
# train_loss= 0.12351085
# test_F1= 0.7529058867641545
# 26
# train_loss= 0.119957834
# test_F1= 0.7599856063332133
# INFO: Early stopping counter 1 of 25
# 27
# train_loss= 0.12929484
# test_F1= 0.750952018278751
# INFO: Early stopping counter 2 of 25
# 28
# train_loss= 0.1233176
# test_F1= 0.7507621951219513
# INFO: Early stopping counter 3 of 25
# 29
# train_loss= 0.103505425
# test_F1= 0.7601038190582128
# INFO: Early stopping counter 4 of 25
# 30
# train_loss= 0.1104728
# test_F1= 0.7488479262672811
# INFO: Early stopping counter 5 of 25
# 31
# train_loss= 0.09518421
# test_F1= 0.7451737451737452
# INFO: Early stopping counter 6 of 25
# 32
# train_loss= 0.10560583
# test_F1= 0.7538519353626457
# INFO: Early stopping counter 7 of 25
# 33
# train_loss= 0.1309021
# test_F1= 0.7562452687358062
# INFO: Early stopping counter 8 of 25
# 34
# train_loss= 0.13459988
# test_F1= 0.7375886524822696
# INFO: Early stopping counter 9 of 25
# 35
# train_loss= 0.13102299
# test_F1= 0.7501915708812261
# INFO: Early stopping counter 10 of 25
# 36
# train_loss= 0.13205056
# test_F1= 0.7591776798825256
# INFO: Early stopping counter 11 of 25
# 37
# train_loss= 0.105188936
# test_F1= 0.7516264829697665
# INFO: Early stopping counter 12 of 25
# 38
# train_loss= 0.11855152
# test_F1= 0.7537001897533206
# INFO: Early stopping counter 13 of 25
# 39
# train_loss= 0.12853664
# test_F1= 0.7555723460521346
# INFO: Early stopping counter 14 of 25
# 40
# train_loss= 0.086791955
# test_F1= 0.7495175607873409
# INFO: Early stopping counter 15 of 25
# 41
# train_loss= 0.125509
# test_F1= 0.7601338787653403
# INFO: Early stopping counter 16 of 25
# 42
# train_loss= 0.13111703
# test_F1= 0.7402750491159135
# 43
# train_loss= 0.12725267
# test_F1= 0.766906474820144
# INFO: Early stopping counter 1 of 25
# 44
# train_loss= 0.10294974
# test_F1= 0.7426786411557985
# INFO: Early stopping counter 2 of 25
# 45
# train_loss= 0.06871171
# test_F1= 0.7487417731320171
# INFO: Early stopping counter 3 of 25
# 46
# train_loss= 0.11372711
# test_F1= 0.7562642369020502
# INFO: Early stopping counter 4 of 25
# 47
# train_loss= 0.11156822
# test_F1= 0.7644703312704768
# INFO: Early stopping counter 5 of 25
# 48
# train_loss= 0.107938245
# test_F1= 0.7421135646687697
# INFO: Early stopping counter 6 of 25
# 49
# train_loss= 0.10483779
# test_F1= 0.7653276955602537
# INFO: Early stopping counter 7 of 25
# 50
# train_loss= 0.093335025
# test_F1= 0.7591185410334347
# INFO: Early stopping counter 8 of 25
# 51
# train_loss= 0.111661196
# test_F1= 0.760075329566855
# INFO: Early stopping counter 9 of 25
# 52
# train_loss= 0.107434034
# test_F1= 0.7542113323124043
# INFO: Early stopping counter 10 of 25
# 53
# train_loss= 0.11006226
# test_F1= 0.7577828397873957
# INFO: Early stopping counter 11 of 25
# 54
# train_loss= 0.11073399
# test_F1= 0.7640366972477064
# INFO: Early stopping counter 12 of 25
# 55
# train_loss= 0.12661743
# test_F1= 0.7601038190582128
# INFO: Early stopping counter 13 of 25
# 56
# train_loss= 0.11134966
# test_F1= 0.7609022556390977
# INFO: Early stopping counter 14 of 25
# 57
# train_loss= 0.107507735
# test_F1= 0.7631874298540965
# INFO: Early stopping counter 15 of 25
# 58
# train_loss= 0.07871925
# test_F1= 0.7658132530120482
# INFO: Early stopping counter 16 of 25
# 59
# train_loss= 0.11720965
# test_F1= 0.7584396099024757
# INFO: Early stopping counter 17 of 25
# 60
# train_loss= 0.09134832
# test_F1= 0.7633928571428572
# INFO: Early stopping counter 18 of 25
# 61
# train_loss= 0.07598332
# test_F1= 0.749708057609965
# INFO: Early stopping counter 19 of 25
# 62
# train_loss= 0.08932596
# test_F1= 0.7672597864768683
# INFO: Early stopping counter 20 of 25
# 63
# train_loss= 0.10353614
# test_F1= 0.7606060606060605
# INFO: Early stopping counter 21 of 25
# 64
# train_loss= 0.095402956
# test_F1= 0.7651205936920222
# INFO: Early stopping counter 22 of 25
# 65
# train_loss= 0.11454989
# test_F1= 0.7552285050348567
# INFO: Early stopping counter 23 of 25
# 66
# train_loss= 0.122910134
# test_F1= 0.7640449438202247
# INFO: Early stopping counter 24 of 25
# 67
# train_loss= 0.0937887
# test_F1= 0.758594346829641
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.688745
# test_F1= 0.4057583852775304
# 1
# train_loss= 0.16148505
# test_F1= 0.6416209371042634
# 2
# train_loss= 0.17365347
# test_F1= 0.700587084148728
# 3
# train_loss= 0.13071805
# test_F1= 0.7149569303054032
# 4
# train_loss= 0.14420515
# test_F1= 0.7264296754250386
# INFO: Early stopping counter 1 of 25
# 5
# train_loss= 0.12670916
# test_F1= 0.7259842519685039
# 6
# train_loss= 0.14255533
# test_F1= 0.7328533535430088
# INFO: Early stopping counter 1 of 25
# 7
# train_loss= 0.10706128
# test_F1= 0.7291099883404586
# INFO: Early stopping counter 2 of 25
# 8
# train_loss= 0.113866776
# test_F1= 0.7284716834755625
# 9
# train_loss= 0.1405085
# test_F1= 0.7353395061728395
# INFO: Early stopping counter 1 of 25
# 10
# train_loss= 0.11968461
# test_F1= 0.7373236751810903
# INFO: Early stopping counter 2 of 25
# 11
# train_loss= 0.13329464
# test_F1= 0.7360000000000001
# INFO: Early stopping counter 3 of 25
# 12
# train_loss= 0.13299966
# test_F1= 0.7329240214888718
# INFO: Early stopping counter 4 of 25
# 13
# train_loss= 0.12310866
# test_F1= 0.7314241486068112
# INFO: Early stopping counter 5 of 25
# 14
# train_loss= 0.11577979
# test_F1= 0.7282651072124755
# INFO: Early stopping counter 6 of 25
# 15
# train_loss= 0.090692535
# test_F1= 0.7269170579029733
# INFO: Early stopping counter 7 of 25
# 16
# train_loss= 0.14971998
# test_F1= 0.7320872274143303
# INFO: Early stopping counter 8 of 25
# 17
# train_loss= 0.11146052
# test_F1= 0.7364787111622554
# 18
# train_loss= 0.13559864
# test_F1= 0.7389830508474576
# INFO: Early stopping counter 1 of 25
# 19
# train_loss= 0.115818
# test_F1= 0.7397572078907436
# INFO: Early stopping counter 2 of 25
# 20
# train_loss= 0.09851612
# test_F1= 0.7345029239766082
# INFO: Early stopping counter 3 of 25
# 21
# train_loss= 0.113842845
# test_F1= 0.7348044909020518
# INFO: Early stopping counter 4 of 25
# 22
# train_loss= 0.091890894
# test_F1= 0.7367205542725174
# 23
# train_loss= 0.102149695
# test_F1= 0.7427055702917771
# 24
# train_loss= 0.13218725
# test_F1= 0.75177304964539
# INFO: Early stopping counter 1 of 25
# 25
# train_loss= 0.122724704
# test_F1= 0.7408844065166795
# INFO: Early stopping counter 2 of 25
# 26
# train_loss= 0.120461315
# test_F1= 0.753265602322206
# INFO: Early stopping counter 3 of 25
# 27
# train_loss= 0.1093055
# test_F1= 0.7382341501361337
# INFO: Early stopping counter 4 of 25
# 28
# train_loss= 0.12209743
# test_F1= 0.7376160990712074
# INFO: Early stopping counter 5 of 25
# 29
# train_loss= 0.13667786
# test_F1= 0.7474671669793621
# INFO: Early stopping counter 6 of 25
# 30
# train_loss= 0.11196315
# test_F1= 0.746451860375911
# 31
# train_loss= 0.10824971
# test_F1= 0.7551319648093842
# INFO: Early stopping counter 1 of 25
# 32
# train_loss= 0.10358019
# test_F1= 0.7438080495356036
# INFO: Early stopping counter 2 of 25
# 33
# train_loss= 0.11339915
# test_F1= 0.7423715720355349
# INFO: Early stopping counter 3 of 25
# 34
# train_loss= 0.12108835
# test_F1= 0.7502841985600606
# 35
# train_loss= 0.101717316
# test_F1= 0.7590007347538573
# 36
# train_loss= 0.10811858
# test_F1= 0.762041696621136
# INFO: Early stopping counter 1 of 25
# 37
# train_loss= 0.09773368
# test_F1= 0.7568569310600445
# INFO: Early stopping counter 2 of 25
# 38
# train_loss= 0.10995565
# test_F1= 0.7586721372622156
# INFO: Early stopping counter 3 of 25
# 39
# train_loss= 0.11113343
# test_F1= 0.7535238095238095
# INFO: Early stopping counter 4 of 25
# 40
# train_loss= 0.109566554
# test_F1= 0.7554552294958615
# 41
# train_loss= 0.13015327
# test_F1= 0.7664023071377072
# INFO: Early stopping counter 1 of 25
# 42
# train_loss= 0.10339953
# test_F1= 0.760709010339734
# INFO: Early stopping counter 2 of 25
# 43
# train_loss= 0.10301014
# test_F1= 0.7557395558901017
# INFO: Early stopping counter 3 of 25
# 44
# train_loss= 0.09091362
# test_F1= 0.7544128933231005
# INFO: Early stopping counter 4 of 25
# 45
# train_loss= 0.10832792
# test_F1= 0.7602078693392725
# 46
# train_loss= 0.1273
# test_F1= 0.7697893972403775
# INFO: Early stopping counter 1 of 25
# 47
# train_loss= 0.09921258
# test_F1= 0.7523291925465838
# INFO: Early stopping counter 2 of 25
# 48
# train_loss= 0.11983625
# test_F1= 0.7489160425699646
# INFO: Early stopping counter 3 of 25
# 49
# train_loss= 0.1124233
# test_F1= 0.7588842185708826
# INFO: Early stopping counter 4 of 25
# 50
# train_loss= 0.107938945
# test_F1= 0.7685683530678148
# INFO: Early stopping counter 5 of 25
# 51
# train_loss= 0.109596744
# test_F1= 0.7445021991203518
# INFO: Early stopping counter 6 of 25
# 52
# train_loss= 0.11812797
# test_F1= 0.7605313092979127
# INFO: Early stopping counter 7 of 25
# 53
# train_loss= 0.11032075
# test_F1= 0.7638940693770983
# INFO: Early stopping counter 8 of 25
# 54
# train_loss= 0.09727076
# test_F1= 0.7658948915839764
# INFO: Early stopping counter 9 of 25
# 55
# train_loss= 0.09620027
# test_F1= 0.7629020194465221
# INFO: Early stopping counter 10 of 25
# 56
# train_loss= 0.118033916
# test_F1= 0.7648809523809523
# INFO: Early stopping counter 11 of 25
# 57
# train_loss= 0.08412053
# test_F1= 0.7616169248205515
# INFO: Early stopping counter 12 of 25
# 58
# train_loss= 0.12629688
# test_F1= 0.7668356263577117
# INFO: Early stopping counter 13 of 25
# 59
# train_loss= 0.10510217
# test_F1= 0.7634328358208955
# INFO: Early stopping counter 14 of 25
# 60
# train_loss= 0.10057992
# test_F1= 0.7623352165725047
# INFO: Early stopping counter 15 of 25
# 61
# train_loss= 0.09253958
# test_F1= 0.7551576488906189
# INFO: Early stopping counter 16 of 25
# 62
# train_loss= 0.09622198
# test_F1= 0.7679477882523568
# INFO: Early stopping counter 17 of 25
# 63
# train_loss= 0.098644674
# test_F1= 0.7578390630902909
# INFO: Early stopping counter 18 of 25
# 64
# train_loss= 0.113423705
# test_F1= 0.7585421412300684
# INFO: Early stopping counter 19 of 25
# 65
# train_loss= 0.07665597
# test_F1= 0.7622247107129525
# INFO: Early stopping counter 20 of 25
# 66
# train_loss= 0.102327205
# test_F1= 0.766889383815887
# INFO: Early stopping counter 21 of 25
# 67
# train_loss= 0.11423485
# test_F1= 0.7643718949609652
# INFO: Early stopping counter 22 of 25
# 68
# train_loss= 0.08469689
# test_F1= 0.7638227755400951
# INFO: Early stopping counter 23 of 25
# 69
# train_loss= 0.110307485
# test_F1= 0.7617951668584578
# INFO: Early stopping counter 24 of 25
# 70
# train_loss= 0.10543225
# test_F1= 0.7576923076923077
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.69545734
# test_F1= 0.36552710256076953
# 1
# train_loss= 0.16501462
# test_F1= 0.64910790144435
# 2
# train_loss= 0.1433663
# test_F1= 0.6921850079744816
# 3
# train_loss= 0.12583454
# test_F1= 0.7089611419508325
# 4
# train_loss= 0.14769858
# test_F1= 0.7217290621381705
# 5
# train_loss= 0.13535737
# test_F1= 0.7294297742058935
# 6
# train_loss= 0.13465463
# test_F1= 0.737471952131638
# INFO: Early stopping counter 1 of 25
# 7
# train_loss= 0.12405215
# test_F1= 0.7257120561841592
# INFO: Early stopping counter 2 of 25
# 8
# train_loss= 0.11780922
# test_F1= 0.7361588392516228
# INFO: Early stopping counter 3 of 25
# 9
# train_loss= 0.12798417
# test_F1= 0.735884804850322
# INFO: Early stopping counter 4 of 25
# 10
# train_loss= 0.14129847
# test_F1= 0.7349443805140008
# INFO: Early stopping counter 5 of 25
# 11
# train_loss= 0.13071394
# test_F1= 0.7308584686774942
# INFO: Early stopping counter 6 of 25
# 12
# train_loss= 0.13272989
# test_F1= 0.7338461538461538
# INFO: Early stopping counter 7 of 25
# 13
# train_loss= 0.12803471
# test_F1= 0.7249114521841795
# 14
# train_loss= 0.108735524
# test_F1= 0.7436849925705795
# INFO: Early stopping counter 1 of 25
# 15
# train_loss= 0.12056951
# test_F1= 0.7372400756143667
# INFO: Early stopping counter 2 of 25
# 16
# train_loss= 0.12988672
# test_F1= 0.7374086889657824
# INFO: Early stopping counter 3 of 25
# 17
# train_loss= 0.12254147
# test_F1= 0.7318784099766174
# INFO: Early stopping counter 4 of 25
# 18
# train_loss= 0.13357037
# test_F1= 0.7397154940407535
# INFO: Early stopping counter 5 of 25
# 19
# train_loss= 0.1366438
# test_F1= 0.7391471379177872
# INFO: Early stopping counter 6 of 25
# 20
# train_loss= 0.114572436
# test_F1= 0.7368421052631577
# INFO: Early stopping counter 7 of 25
# 21
# train_loss= 0.13458425
# test_F1= 0.7365570599613153
# INFO: Early stopping counter 8 of 25
# 22
# train_loss= 0.120225154
# test_F1= 0.7414187643020594
# INFO: Early stopping counter 9 of 25
# 23
# train_loss= 0.118511885
# test_F1= 0.7434831885153004
# INFO: Early stopping counter 10 of 25
# 24
# train_loss= 0.12437587
# test_F1= 0.7337278106508875
# 25
# train_loss= 0.12055519
# test_F1= 0.7459540835528792
# INFO: Early stopping counter 1 of 25
# 26
# train_loss= 0.112872824
# test_F1= 0.7405112316034081
# INFO: Early stopping counter 2 of 25
# 27
# train_loss= 0.10126373
# test_F1= 0.7379553466509989
# INFO: Early stopping counter 3 of 25
# 28
# train_loss= 0.124560654
# test_F1= 0.7463823305407462
# INFO: Early stopping counter 4 of 25
# 29
# train_loss= 0.09654481
# test_F1= 0.7334924423229913
# INFO: Early stopping counter 5 of 25
# 30
# train_loss= 0.08611678
# test_F1= 0.7478194918467955
# 31
# train_loss= 0.12538153
# test_F1= 0.7499999999999999
# INFO: Early stopping counter 1 of 25
# 32
# train_loss= 0.081579134
# test_F1= 0.751219512195122
# INFO: Early stopping counter 2 of 25
# 33
# train_loss= 0.113796115
# test_F1= 0.7472018525665767
# INFO: Early stopping counter 3 of 25
# 34
# train_loss= 0.10643486
# test_F1= 0.741486068111455
# 35
# train_loss= 0.09757074
# test_F1= 0.7581699346405228
# INFO: Early stopping counter 1 of 25
# 36
# train_loss= 0.11789888
# test_F1= 0.7473968376397994
# INFO: Early stopping counter 2 of 25
# 37
# train_loss= 0.10514304
# test_F1= 0.7475989243180945
# INFO: Early stopping counter 3 of 25
# 38
# train_loss= 0.10046561
# test_F1= 0.7450980392156863
# INFO: Early stopping counter 4 of 25
# 39
# train_loss= 0.11561073
# test_F1= 0.7561705310396412
# INFO: Early stopping counter 5 of 25
# 40
# train_loss= 0.08817036
# test_F1= 0.7504820671037408
# INFO: Early stopping counter 6 of 25
# 41
# train_loss= 0.1269334
# test_F1= 0.7489394523717703
# INFO: Early stopping counter 7 of 25
# 42
# train_loss= 0.09516023
# test_F1= 0.7593850554165178
# INFO: Early stopping counter 8 of 25
# 43
# train_loss= 0.11510053
# test_F1= 0.7548757170172083
# INFO: Early stopping counter 9 of 25
# 44
# train_loss= 0.10405147
# test_F1= 0.7537878787878787
# INFO: Early stopping counter 10 of 25
# 45
# train_loss= 0.14064486
# test_F1= 0.7577729573391179
# INFO: Early stopping counter 11 of 25
# 46
# train_loss= 0.120602176
# test_F1= 0.7408284023668638
# INFO: Early stopping counter 12 of 25
# 47
# train_loss= 0.099976316
# test_F1= 0.7590048273301152
# INFO: Early stopping counter 13 of 25
# 48
# train_loss= 0.12051775
# test_F1= 0.7466977466977466
# INFO: Early stopping counter 14 of 25
# 49
# train_loss= 0.10557683
# test_F1= 0.7565543071161048
# INFO: Early stopping counter 15 of 25
# 50
# train_loss= 0.10129935
# test_F1= 0.75
# INFO: Early stopping counter 16 of 25
# 51
# train_loss= 0.10525102
# test_F1= 0.7415908191531458
# INFO: Early stopping counter 17 of 25
# 52
# train_loss= 0.11723606
# test_F1= 0.7410327158060701
# INFO: Early stopping counter 18 of 25
# 53
# train_loss= 0.09862923
# test_F1= 0.7578870139398385
# INFO: Early stopping counter 19 of 25
# 54
# train_loss= 0.12563507
# test_F1= 0.7558578987150416
# INFO: Early stopping counter 20 of 25
# 55
# train_loss= 0.097324744
# test_F1= 0.7540489642184558
# INFO: Early stopping counter 21 of 25
# 56
# train_loss= 0.102007285
# test_F1= 0.7580283793876028
# INFO: Early stopping counter 22 of 25
# 57
# train_loss= 0.09470981
# test_F1= 0.7513307984790876
# INFO: Early stopping counter 23 of 25
# 58
# train_loss= 0.12505732
# test_F1= 0.7559232794283565
# INFO: Early stopping counter 24 of 25
# 59
# train_loss= 0.10649619
# test_F1= 0.7600896860986547
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.7159287
# test_F1= 0.3593264248704663
# 1
# train_loss= 0.14984491
# test_F1= 0.6422174840085288
# 2
# train_loss= 0.18086308
# test_F1= 0.6892700438771441
# 3
# train_loss= 0.12340522
# test_F1= 0.7067551737602499
# 4
# train_loss= 0.14464703
# test_F1= 0.7101391650099403
# 5
# train_loss= 0.12670779
# test_F1= 0.7267843438219496
# INFO: Early stopping counter 1 of 25
# 6
# train_loss= 0.11211914
# test_F1= 0.7256499805975941
# INFO: Early stopping counter 2 of 25
# 7
# train_loss= 0.14668518
# test_F1= 0.7266327727806022
# INFO: Early stopping counter 3 of 25
# 8
# train_loss= 0.13767081
# test_F1= 0.7258444619010213
# 9
# train_loss= 0.15889984
# test_F1= 0.7384500745156485
# INFO: Early stopping counter 1 of 25
# 10
# train_loss= 0.12816782
# test_F1= 0.7305759567066099
# INFO: Early stopping counter 2 of 25
# 11
# train_loss= 0.128529
# test_F1= 0.7317454119484575
# INFO: Early stopping counter 3 of 25
# 12
# train_loss= 0.15006109
# test_F1= 0.7269828616978876
# INFO: Early stopping counter 4 of 25
# 13
# train_loss= 0.1356271
# test_F1= 0.7388535031847134
# INFO: Early stopping counter 5 of 25
# 14
# train_loss= 0.12257826
# test_F1= 0.7370803470388532
# INFO: Early stopping counter 6 of 25
# 15
# train_loss= 0.115698054
# test_F1= 0.7274167987321711
# INFO: Early stopping counter 7 of 25
# 16
# train_loss= 0.11953177
# test_F1= 0.7390476190476192
# 17
# train_loss= 0.11303036
# test_F1= 0.7453737971872686
# INFO: Early stopping counter 1 of 25
# 18
# train_loss= 0.12172191
# test_F1= 0.7343446129910541
# INFO: Early stopping counter 2 of 25
# 19
# train_loss= 0.12259878
# test_F1= 0.740968485780169
# INFO: Early stopping counter 3 of 25
# 20
# train_loss= 0.12885565
# test_F1= 0.7385697538100819
# INFO: Early stopping counter 4 of 25
# 21
# train_loss= 0.100610666
# test_F1= 0.7431365174877774
# INFO: Early stopping counter 5 of 25
# 22
# train_loss= 0.11814285
# test_F1= 0.7438142367719833
# INFO: Early stopping counter 6 of 25
# 23
# train_loss= 0.1259533
# test_F1= 0.7432277756581458
# 24
# train_loss= 0.1309672
# test_F1= 0.7503692762186114
# INFO: Early stopping counter 1 of 25
# 25
# train_loss= 0.12653434
# test_F1= 0.7283702213279679
# INFO: Early stopping counter 2 of 25
# 26
# train_loss= 0.119402066
# test_F1= 0.7483095416979715
# INFO: Early stopping counter 3 of 25
# 27
# train_loss= 0.13213211
# test_F1= 0.738160469667319
# INFO: Early stopping counter 4 of 25
# 28
# train_loss= 0.124162614
# test_F1= 0.7509349289454001
# INFO: Early stopping counter 5 of 25
# 29
# train_loss= 0.15597585
# test_F1= 0.7426127527216174
# 30
# train_loss= 0.11653801
# test_F1= 0.7568377669539154
# 31
# train_loss= 0.11207557
# test_F1= 0.7594012413289521
# INFO: Early stopping counter 1 of 25
# 32
# train_loss= 0.12533975
# test_F1= 0.746257197696737
# INFO: Early stopping counter 2 of 25
# 33
# train_loss= 0.1110129
# test_F1= 0.7420109119251754
# 34
# train_loss= 0.12057989
# test_F1= 0.7656082768462363
# INFO: Early stopping counter 1 of 25
# 35
# train_loss= 0.13359539
# test_F1= 0.7594654788418708
# INFO: Early stopping counter 2 of 25
# 36
# train_loss= 0.10049675
# test_F1= 0.758364312267658
# INFO: Early stopping counter 3 of 25
# 37
# train_loss= 0.09627544
# test_F1= 0.7545454545454547
# INFO: Early stopping counter 4 of 25
# 38
# train_loss= 0.10304871
# test_F1= 0.7553712777987185
# INFO: Early stopping counter 5 of 25
# 39
# train_loss= 0.117868386
# test_F1= 0.7575982209043736
# INFO: Early stopping counter 6 of 25
# 40
# train_loss= 0.11150551
# test_F1= 0.757847533632287
# INFO: Early stopping counter 7 of 25
# 41
# train_loss= 0.0975413
# test_F1= 0.7543461829176115
# INFO: Early stopping counter 8 of 25
# 42
# train_loss= 0.12322985
# test_F1= 0.7542726927459172
# INFO: Early stopping counter 9 of 25
# 43
# train_loss= 0.090917915
# test_F1= 0.7476708074534162
# INFO: Early stopping counter 10 of 25
# 44
# train_loss= 0.13548863
# test_F1= 0.7541729893778452
# INFO: Early stopping counter 11 of 25
# 45
# train_loss= 0.094182014
# test_F1= 0.7423887587822016
# INFO: Early stopping counter 12 of 25
# 46
# train_loss= 0.12806834
# test_F1= 0.7544128933231005
# INFO: Early stopping counter 13 of 25
# 47
# train_loss= 0.10624042
# test_F1= 0.7594936708860759
# INFO: Early stopping counter 14 of 25
# 48
# train_loss= 0.09728022
# test_F1= 0.7527703477264044
# INFO: Early stopping counter 15 of 25
# 49
# train_loss= 0.112035304
# test_F1= 0.764378478664193
# INFO: Early stopping counter 16 of 25
# 50
# train_loss= 0.10465871
# test_F1= 0.7547312641937927
# INFO: Early stopping counter 17 of 25
# 51
# train_loss= 0.11158511
# test_F1= 0.7620111731843575
# INFO: Early stopping counter 18 of 25
# 52
# train_loss= 0.09408656
# test_F1= 0.765090909090909
# INFO: Early stopping counter 19 of 25
# 53
# train_loss= 0.09807528
# test_F1= 0.7494235203689469
# INFO: Early stopping counter 20 of 25
# 54
# train_loss= 0.08351511
# test_F1= 0.760942760942761
# INFO: Early stopping counter 21 of 25
# 55
# train_loss= 0.120621145
# test_F1= 0.7549618320610688
# INFO: Early stopping counter 22 of 25
# 56
# train_loss= 0.093948446
# test_F1= 0.7475614514241122
# INFO: Early stopping counter 23 of 25
# 57
# train_loss= 0.09999111
# test_F1= 0.7661909989023051
# INFO: Early stopping counter 24 of 25
# 58
# train_loss= 0.1281013
# test_F1= 0.7490317583268784
# 59
# train_loss= 0.103914835
# test_F1= 0.7695668001456133
# INFO: Early stopping counter 1 of 25
# 60
# train_loss= 0.08742061
# test_F1= 0.7569207432688662
# INFO: Early stopping counter 2 of 25
# 61
# train_loss= 0.11457951
# test_F1= 0.761055369751022
# INFO: Early stopping counter 3 of 25
# 62
# train_loss= 0.0777677
# test_F1= 0.7647918188458729
# INFO: Early stopping counter 4 of 25
# 63
# train_loss= 0.0902158
# test_F1= 0.763582966226138
# INFO: Early stopping counter 5 of 25
# 64
# train_loss= 0.07429128
# test_F1= 0.7559478127398312
# INFO: Early stopping counter 6 of 25
# 65
# train_loss= 0.09534339
# test_F1= 0.7652802893309223
# INFO: Early stopping counter 7 of 25
# 66
# train_loss= 0.082585275
# test_F1= 0.7608286252354047
# INFO: Early stopping counter 8 of 25
# 67
# train_loss= 0.1031241
# test_F1= 0.7595607724346839
# INFO: Early stopping counter 9 of 25
# 68
# train_loss= 0.097854674
# test_F1= 0.76410998552822
# INFO: Early stopping counter 10 of 25
# 69
# train_loss= 0.08662473
# test_F1= 0.759789156626506
# INFO: Early stopping counter 11 of 25
# 70
# train_loss= 0.09267741
# test_F1= 0.7626546681664792
# INFO: Early stopping counter 12 of 25
# 71
# train_loss= 0.091341265
# test_F1= 0.7568597560975608
# INFO: Early stopping counter 13 of 25
# 72
# train_loss= 0.08462848
# test_F1= 0.7616560984707198
# INFO: Early stopping counter 14 of 25
# 73
# train_loss= 0.09603986
# test_F1= 0.7665327000365364
# INFO: Early stopping counter 15 of 25
# 74
# train_loss= 0.08213866
# test_F1= 0.734906037584966
# INFO: Early stopping counter 16 of 25
# 75
# train_loss= 0.10020067
# test_F1= 0.7608286252354047
# INFO: Early stopping counter 17 of 25
# 76
# train_loss= 0.08560011
# test_F1= 0.7564766839378237
# INFO: Early stopping counter 18 of 25
# 77
# train_loss= 0.105761155
# test_F1= 0.7461869378177551
# INFO: Early stopping counter 19 of 25
# 78
# train_loss= 0.09447974
# test_F1= 0.7676333691371285
# INFO: Early stopping counter 20 of 25
# 79
# train_loss= 0.09874837
# test_F1= 0.7672819399203763
# INFO: Early stopping counter 21 of 25
# 80
# train_loss= 0.08016786
# test_F1= 0.762680488707886
# INFO: Early stopping counter 22 of 25
# 81
# train_loss= 0.09383869
# test_F1= 0.757847533632287
# INFO: Early stopping counter 23 of 25
# 82
# train_loss= 0.1037711
# test_F1= 0.76659678546471
# INFO: Early stopping counter 24 of 25
# 83
# train_loss= 0.09410918
# test_F1= 0.763157894736842
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.7195058
# test_F1= 0.32186759896244505
# 1
# train_loss= 0.14031214
# test_F1= 0.6373254337706306
# 2
# train_loss= 0.14035994
# test_F1= 0.6761479073547338
# 3
# train_loss= 0.15414613
# test_F1= 0.7014925373134328
# 4
# train_loss= 0.12813571
# test_F1= 0.7162214479287651
# 5
# train_loss= 0.14608942
# test_F1= 0.7195932733672273
# 6
# train_loss= 0.17424977
# test_F1= 0.7309451219512195
# INFO: Early stopping counter 1 of 25
# 7
# train_loss= 0.13763392
# test_F1= 0.7286702536510377
# INFO: Early stopping counter 2 of 25
# 8
# train_loss= 0.14144862
# test_F1= 0.7290944123314066
# 9
# train_loss= 0.117568426
# test_F1= 0.7352264006139678
# 10
# train_loss= 0.12389218
# test_F1= 0.741514360313316
# INFO: Early stopping counter 1 of 25
# 11
# train_loss= 0.14114837
# test_F1= 0.736360167874857
# 12
# train_loss= 0.14257264
# test_F1= 0.7472687545520758
# INFO: Early stopping counter 1 of 25
# 13
# train_loss= 0.14865988
# test_F1= 0.7392614920874152
# INFO: Early stopping counter 2 of 25
# 14
# train_loss= 0.14069033
# test_F1= 0.7431365174877774
# INFO: Early stopping counter 3 of 25
# 15
# train_loss= 0.12419908
# test_F1= 0.7428571428571429
# INFO: Early stopping counter 4 of 25
# 16
# train_loss= 0.14113328
# test_F1= 0.7412746585735963
# INFO: Early stopping counter 5 of 25
# 17
# train_loss= 0.13697132
# test_F1= 0.7361915797605254
# 18
# train_loss= 0.12197486
# test_F1= 0.7531899380240613
# INFO: Early stopping counter 1 of 25
# 19
# train_loss= 0.12814097
# test_F1= 0.735759493670886
# INFO: Early stopping counter 2 of 25
# 20
# train_loss= 0.113543354
# test_F1= 0.7551470588235293
# INFO: Early stopping counter 3 of 25
# 21
# train_loss= 0.14080977
# test_F1= 0.745607333842628
# INFO: Early stopping counter 4 of 25
# 22
# train_loss= 0.12220608
# test_F1= 0.7535159141376757
# INFO: Early stopping counter 5 of 25
# 23
# train_loss= 0.120627776
# test_F1= 0.7482785003825554
# INFO: Early stopping counter 6 of 25
# 24
# train_loss= 0.10158777
# test_F1= 0.7471931862175766
# INFO: Early stopping counter 7 of 25
# 25
# train_loss= 0.12222603
# test_F1= 0.7527368818422046
# INFO: Early stopping counter 8 of 25
# 26
# train_loss= 0.117522754
# test_F1= 0.7505755947812739
# 27
# train_loss= 0.11883323
# test_F1= 0.7553712777987185
# INFO: Early stopping counter 1 of 25
# 28
# train_loss= 0.095618986
# test_F1= 0.7414403778040141
# INFO: Early stopping counter 2 of 25
# 29
# train_loss= 0.106635734
# test_F1= 0.756815703380589
# INFO: Early stopping counter 3 of 25
# 30
# train_loss= 0.12999587
# test_F1= 0.7503828483920367
# INFO: Early stopping counter 4 of 25
# 31
# train_loss= 0.12431753
# test_F1= 0.7523701175578308
# INFO: Early stopping counter 5 of 25
# 32
# train_loss= 0.10400282
# test_F1= 0.746418892760356
# 33
# train_loss= 0.14847384
# test_F1= 0.760709010339734
# INFO: Early stopping counter 1 of 25
# 34
# train_loss= 0.12681895
# test_F1= 0.7526964560862867
# INFO: Early stopping counter 2 of 25
# 35
# train_loss= 0.11215159
# test_F1= 0.7520122652357225
# INFO: Early stopping counter 3 of 25
# 36
# train_loss= 0.09322959
# test_F1= 0.7583615182262308
# INFO: Early stopping counter 4 of 25
# 37
# train_loss= 0.09090261
# test_F1= 0.7562076749435666
# INFO: Early stopping counter 5 of 25
# 38
# train_loss= 0.116584495
# test_F1= 0.759009009009009
# INFO: Early stopping counter 6 of 25
# 39
# train_loss= 0.12212972
# test_F1= 0.7593144560357673
# INFO: Early stopping counter 7 of 25
# 40
# train_loss= 0.1206425
# test_F1= 0.7553516819571866
# INFO: Early stopping counter 8 of 25
# 41
# train_loss= 0.10301863
# test_F1= 0.7582831325301205
# 42
# train_loss= 0.10397135
# test_F1= 0.7651458489154823
# INFO: Early stopping counter 1 of 25
# 43
# train_loss= 0.1194527
# test_F1= 0.7379721669980119
# INFO: Early stopping counter 2 of 25
# 44
# train_loss= 0.11591053
# test_F1= 0.7628942486085343
# INFO: Early stopping counter 3 of 25
# 45
# train_loss= 0.10086256
# test_F1= 0.7605214152700187
# INFO: Early stopping counter 4 of 25
# 46
# train_loss= 0.11254549
# test_F1= 0.7555898226676947
# INFO: Early stopping counter 5 of 25
# 47
# train_loss= 0.12126242
# test_F1= 0.7530864197530865
# INFO: Early stopping counter 6 of 25
# 48
# train_loss= 0.10124999
# test_F1= 0.7617636161541311
# INFO: Early stopping counter 7 of 25
# 49
# train_loss= 0.10037588
# test_F1= 0.7627872498146776
# INFO: Early stopping counter 8 of 25
# 50
# train_loss= 0.09551199
# test_F1= 0.7664845173041895
# INFO: Early stopping counter 9 of 25
# 51
# train_loss= 0.08870568
# test_F1= 0.7500974658869395
# INFO: Early stopping counter 10 of 25
# 52
# train_loss= 0.09926224
# test_F1= 0.7643825577134481
# INFO: Early stopping counter 11 of 25
# 53
# train_loss= 0.10439763
# test_F1= 0.7431952662721895
# INFO: Early stopping counter 12 of 25
# 54
# train_loss= 0.09432507
# test_F1= 0.7665726375176306
# INFO: Early stopping counter 13 of 25
# 55
# train_loss= 0.093189746
# test_F1= 0.7500965623792971
# INFO: Early stopping counter 14 of 25
# 56
# train_loss= 0.08653118
# test_F1= 0.7645348837209303
# INFO: Early stopping counter 15 of 25
# 57
# train_loss= 0.08853313
# test_F1= 0.7612612612612611
# INFO: Early stopping counter 16 of 25
# 58
# train_loss= 0.07570635
# test_F1= 0.7632375189107412
# INFO: Early stopping counter 17 of 25
# 59
# train_loss= 0.10688673
# test_F1= 0.7590361445783134
# INFO: Early stopping counter 18 of 25
# 60
# train_loss= 0.088825285
# test_F1= 0.7614100185528757
# INFO: Early stopping counter 19 of 25
# 61
# train_loss= 0.08727045
# test_F1= 0.7585421412300684
# INFO: Early stopping counter 20 of 25
# 62
# train_loss= 0.108730555
# test_F1= 0.7661469933184855
# INFO: Early stopping counter 21 of 25
# 63
# train_loss= 0.08841226
# test_F1= 0.7644927536231884
# 64
# train_loss= 0.10318632
# test_F1= 0.7676620538965768
# INFO: Early stopping counter 1 of 25
# 65
# train_loss= 0.08650562
# test_F1= 0.7651792245793709
# INFO: Early stopping counter 2 of 25
# 66
# train_loss= 0.112295866
# test_F1= 0.7629764065335752
# INFO: Early stopping counter 3 of 25
# 67
# train_loss= 0.101748765
# test_F1= 0.7648578811369509
# INFO: Early stopping counter 4 of 25
# 68
# train_loss= 0.0906647
# test_F1= 0.7524140594824257
# INFO: Early stopping counter 5 of 25
# 69
# train_loss= 0.09477244
# test_F1= 0.7594070695553022
# INFO: Early stopping counter 6 of 25
# 70
# train_loss= 0.07630956
# test_F1= 0.7617977528089889
# INFO: Early stopping counter 7 of 25
# 71
# train_loss= 0.07743948
# test_F1= 0.760342899739098
# INFO: Early stopping counter 8 of 25
# 72
# train_loss= 0.124439664
# test_F1= 0.7580218950547376
# INFO: Early stopping counter 9 of 25
# 73
# train_loss= 0.07678954
# test_F1= 0.758751902587519
# INFO: Early stopping counter 10 of 25
# 74
# train_loss= 0.09448522
# test_F1= 0.7630792227204783
# INFO: Early stopping counter 11 of 25
# 75
# train_loss= 0.12357053
# test_F1= 0.7640871525169045
# INFO: Early stopping counter 12 of 25
# 76
# train_loss= 0.10155119
# test_F1= 0.7604049493813273
# INFO: Early stopping counter 13 of 25
# 77
# train_loss= 0.10049704
# test_F1= 0.7582659808963996
# INFO: Early stopping counter 14 of 25
# 78
# train_loss= 0.090898015
# test_F1= 0.7620804131316857
# INFO: Early stopping counter 15 of 25
# 79
# train_loss= 0.09263628
# test_F1= 0.7650273224043715
# INFO: Early stopping counter 16 of 25
# 80
# train_loss= 0.082504965
# test_F1= 0.7493198600855032
# INFO: Early stopping counter 17 of 25
# 81
# train_loss= 0.08979221
# test_F1= 0.7499030632027918
# INFO: Early stopping counter 18 of 25
# 82
# train_loss= 0.080311894
# test_F1= 0.7596613912403385
# INFO: Early stopping counter 19 of 25
# 83
# train_loss= 0.082938224
# test_F1= 0.7630264097073518
# INFO: Early stopping counter 20 of 25
# 84
# train_loss= 0.09021477
# test_F1= 0.7598828696925329
# INFO: Early stopping counter 21 of 25
# 85
# train_loss= 0.12748243
# test_F1= 0.7472783825816485
# INFO: Early stopping counter 22 of 25
# 86
# train_loss= 0.10068857
# test_F1= 0.7643825577134481
# INFO: Early stopping counter 23 of 25
# 87
# train_loss= 0.07372956
# test_F1= 0.7635960044395116
# INFO: Early stopping counter 24 of 25
# 88
# train_loss= 0.10033672
# test_F1= 0.7595505617977529
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.70829284
# test_F1= 0.33751643360822275
# 1
# train_loss= 0.16115083
# test_F1= 0.6305841924398625
# 2
# train_loss= 0.13166872
# test_F1= 0.6822958771220695
# 3
# train_loss= 0.1294462
# test_F1= 0.7077769049489394
# 4
# train_loss= 0.14177246
# test_F1= 0.7195972114639814
# INFO: Early stopping counter 1 of 25
# 5
# train_loss= 0.1311328
# test_F1= 0.7166666666666667
# 6
# train_loss= 0.13088697
# test_F1= 0.727969348659004
# 7
# train_loss= 0.13772362
# test_F1= 0.7319311663479924
# INFO: Early stopping counter 1 of 25
# 8
# train_loss= 0.13141552
# test_F1= 0.7330524703178859
# INFO: Early stopping counter 2 of 25
# 9
# train_loss= 0.13905714
# test_F1= 0.7270597422881687
# INFO: Early stopping counter 3 of 25
# 10
# train_loss= 0.15818696
# test_F1= 0.7309486780715395
# 11
# train_loss= 0.15092018
# test_F1= 0.7347725520431766
# INFO: Early stopping counter 1 of 25
# 12
# train_loss= 0.12432614
# test_F1= 0.7359938603223332
# 13
# train_loss= 0.11641824
# test_F1= 0.7421431276031807
# INFO: Early stopping counter 1 of 25
# 14
# train_loss= 0.12178763
# test_F1= 0.7431365174877774
# INFO: Early stopping counter 2 of 25
# 15
# train_loss= 0.115156054
# test_F1= 0.7326810176125244
# 16
# train_loss= 0.09958377
# test_F1= 0.7453042824943651
# INFO: Early stopping counter 1 of 25
# 17
# train_loss= 0.10959089
# test_F1= 0.744874715261959
# 18
# train_loss= 0.14774989
# test_F1= 0.747513389441469
# INFO: Early stopping counter 1 of 25
# 19
# train_loss= 0.13105491
# test_F1= 0.748314606741573
# INFO: Early stopping counter 2 of 25
# 20
# train_loss= 0.10125461
# test_F1= 0.7436190476190477
# 21
# train_loss= 0.13984743
# test_F1= 0.752562225475842
# 22
# train_loss= 0.1347584
# test_F1= 0.7583482944344704
# INFO: Early stopping counter 1 of 25
# 23
# train_loss= 0.13209279
# test_F1= 0.7460555972952667
# INFO: Early stopping counter 2 of 25
# 24
# train_loss= 0.12035824
# test_F1= 0.7562225475841874
# INFO: Early stopping counter 3 of 25
# 25
# train_loss= 0.1150565
# test_F1= 0.7445652173913044
# INFO: Early stopping counter 4 of 25
# 26
# train_loss= 0.12835911
# test_F1= 0.7565570742519393
# INFO: Early stopping counter 5 of 25
# 27
# train_loss= 0.094558865
# test_F1= 0.7499056959637872
# INFO: Early stopping counter 6 of 25
# 28
# train_loss= 0.10486701
# test_F1= 0.7524528301886794
# INFO: Early stopping counter 7 of 25
# 29
# train_loss= 0.13257073
# test_F1= 0.7528799702712747
# INFO: Early stopping counter 8 of 25
# 30
# train_loss= 0.11894558
# test_F1= 0.7529322739311389
# INFO: Early stopping counter 9 of 25
# 31
# train_loss= 0.098643795
# test_F1= 0.7356775977874358
# INFO: Early stopping counter 10 of 25
# 32
# train_loss= 0.102401584
# test_F1= 0.7513348588863463
# INFO: Early stopping counter 11 of 25
# 33
# train_loss= 0.12615938
# test_F1= 0.7543278084714548
# INFO: Early stopping counter 12 of 25
# 34
# train_loss= 0.12974715
# test_F1= 0.7553584626755359
# INFO: Early stopping counter 13 of 25
# 35
# train_loss= 0.11283038
# test_F1= 0.7442405310425615
# INFO: Early stopping counter 14 of 25
# 36
# train_loss= 0.08888379
# test_F1= 0.7400394477317553
# INFO: Early stopping counter 15 of 25
# 37
# train_loss= 0.120033525
# test_F1= 0.7541713014460512
# INFO: Early stopping counter 16 of 25
# 38
# train_loss= 0.08797129
# test_F1= 0.7534709193245778
# INFO: Early stopping counter 17 of 25
# 39
# train_loss= 0.10780169
# test_F1= 0.751054852320675
# INFO: Early stopping counter 18 of 25
# 40
# train_loss= 0.11260806
# test_F1= 0.7525655644241732
# INFO: Early stopping counter 19 of 25
# 41
# train_loss= 0.10639851
# test_F1= 0.7563025210084033
# INFO: Early stopping counter 20 of 25
# 42
# train_loss= 0.10900212
# test_F1= 0.7474207107374855
# INFO: Early stopping counter 21 of 25
# 43
# train_loss= 0.11223189
# test_F1= 0.7580071174377224
# INFO: Early stopping counter 22 of 25
# 44
# train_loss= 0.14766064
# test_F1= 0.756350626118068
# INFO: Early stopping counter 23 of 25
# 45
# train_loss= 0.11798823
# test_F1= 0.7587957925281102
# INFO: Early stopping counter 24 of 25
# 46
# train_loss= 0.095876455
# test_F1= 0.7495175607873409
# INFO: Early stopping counter 25 of 25
# INFO: Early stopping
# Early Stoppning!!!

# %%
print(f"NeuralNet #optimized F1 MEAN {np.mean(f1_scores)}")
print(f"NeuralNet #optimized F1 STD {np.std(f1_scores)}")
# Out:
# NeuralNet #optimized F1 MEAN 0.7485824474742111
# NeuralNet #optimized F1 STD 0.00845260573141541

# %% [markdown]
# Благодаря оптимизации гиперпараметров удалось улучшить качество на кросс-валидации с 0.73 до 0.75 на 3-fold кросс валидации и до 74.9 на 10-fold кросс-валидации. При этом удалось снизить стандартное отклонение с 0.013 до 0.008.

# %% [markdown]
# ## 4. Проверка на тестовой выборке

# %% [markdown]
# Проверим качество финальной модели на тестовой выборке.

# %%
best_net = Perceptron(input_dim=768, 
                      num_layers=best_params['num_layers'], 
                      hidden_dim=best_params['hidden_dim'], 
                      activation=activation_dict[best_params['activation']],
                      output_dim=1, 
                      p=best_params['p'])

best_net.apply(init_weights)

best_net.train()
trainer(model=best_net, 
        datasettrain=dataset_train, 
        datasetvalid=dataset_valid, 
        loss_function=t.nn.BCELoss(), 
        optimizer=t.optim.Adam(best_net.parameters(), lr=best_params['learning_rate']), 
        epochs=500, 
        check_val_metric=1, 
        patience=10,
        min_delta=0.001, 
        batch_size=best_params['batch_size'])
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# train_loss= 0.66612285
# test_F1= 0.3653395784543326
# 1
# train_loss= 0.1741586
# test_F1= 0.6526315789473685
# 2
# train_loss= 0.15229735
# test_F1= 0.6878048780487805
# 3
# train_loss= 0.15475649
# test_F1= 0.7133411124076235
# 4
# train_loss= 0.13968232
# test_F1= 0.7155747351902707
# 5
# train_loss= 0.111509584
# test_F1= 0.719652036378015
# 6
# train_loss= 0.13884172
# test_F1= 0.7272018706157443
# 7
# train_loss= 0.1665387
# test_F1= 0.7285436893203882
# 8
# train_loss= 0.12657876
# test_F1= 0.7316698656429943
# INFO: Early stopping counter 1 of 10
# 9
# train_loss= 0.15164332
# test_F1= 0.7288333983612952
# 10
# train_loss= 0.13961048
# test_F1= 0.7407689379520367
# INFO: Early stopping counter 1 of 10
# 11
# train_loss= 0.15177232
# test_F1= 0.7356948228882834
# INFO: Early stopping counter 2 of 10
# 12
# train_loss= 0.11662787
# test_F1= 0.7337509788566955
# INFO: Early stopping counter 3 of 10
# 13
# train_loss= 0.11404749
# test_F1= 0.7397683397683397
# 14
# train_loss= 0.10908087
# test_F1= 0.7437185929648241
# INFO: Early stopping counter 1 of 10
# 15
# train_loss= 0.12127301
# test_F1= 0.7410817031070195
# INFO: Early stopping counter 2 of 10
# 16
# train_loss= 0.11195132
# test_F1= 0.7386318703044681
# 17
# train_loss= 0.14423598
# test_F1= 0.7469604863221885
# INFO: Early stopping counter 1 of 10
# 18
# train_loss= 0.10527162
# test_F1= 0.7473282442748093
# INFO: Early stopping counter 2 of 10
# 19
# train_loss= 0.11716983
# test_F1= 0.746604578967792
# 20
# train_loss= 0.11872855
# test_F1= 0.7529411764705882
# 21
# train_loss= 0.13769087
# test_F1= 0.7543593631539045
# INFO: Early stopping counter 1 of 10
# 22
# train_loss= 0.13430294
# test_F1= 0.7459080280592362
# INFO: Early stopping counter 2 of 10
# 23
# train_loss= 0.1199498
# test_F1= 0.7545317220543807
# INFO: Early stopping counter 3 of 10
# 24
# train_loss= 0.123240665
# test_F1= 0.7360000000000001
# 25
# train_loss= 0.13961366
# test_F1= 0.7558451513990034
# 26
# train_loss= 0.12796079
# test_F1= 0.7583115427717594
# INFO: Early stopping counter 1 of 10
# 27
# train_loss= 0.10191032
# test_F1= 0.7527131782945737
# INFO: Early stopping counter 2 of 10
# 28
# train_loss= 0.13717584
# test_F1= 0.7465726596161378
# INFO: Early stopping counter 3 of 10
# 29
# train_loss= 0.10523328
# test_F1= 0.7560507107184018
# INFO: Early stopping counter 4 of 10
# 30
# train_loss= 0.11213907
# test_F1= 0.7562642369020502
# INFO: Early stopping counter 5 of 10
# 31
# train_loss= 0.10621776
# test_F1= 0.7518504090377872
# INFO: Early stopping counter 6 of 10
# 32
# train_loss= 0.10650012
# test_F1= 0.7452380952380953
# 33
# train_loss= 0.0907508
# test_F1= 0.7642276422764228
# INFO: Early stopping counter 1 of 10
# 34
# train_loss= 0.09906094
# test_F1= 0.7478397486252946
# INFO: Early stopping counter 2 of 10
# 35
# train_loss= 0.08470845
# test_F1= 0.7544128933231005
# INFO: Early stopping counter 3 of 10
# 36
# train_loss= 0.13422486
# test_F1= 0.7492236024844721
# INFO: Early stopping counter 4 of 10
# 37
# train_loss= 0.095530644
# test_F1= 0.7549514563106795
# INFO: Early stopping counter 5 of 10
# 38
# train_loss= 0.1083117
# test_F1= 0.7601057801284472
# INFO: Early stopping counter 6 of 10
# 39
# train_loss= 0.11395486
# test_F1= 0.7614366729678639
# INFO: Early stopping counter 7 of 10
# 40
# train_loss= 0.09536237
# test_F1= 0.7530959752321983
# INFO: Early stopping counter 8 of 10
# 41
# train_loss= 0.10955084
# test_F1= 0.750097162844928
# INFO: Early stopping counter 9 of 10
# 42
# train_loss= 0.105456755
# test_F1= 0.750776397515528
# INFO: Early stopping counter 10 of 10
# INFO: Early stopping
# Early Stoppning!!!

# %%
best_net.eval()
f1, report = testing(best_net, dataset_test)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     14311
#            1       0.82      0.70      0.76      1619
#
#     accuracy                           0.95     15930
#    macro avg       0.89      0.84      0.86     15930
# weighted avg       0.95      0.95      0.95     15930

# %%
f1
# Out:
# 0.7552587646076795

# %% [markdown]
# Нам удалось получить модель, которая показывает качество на тестовой выборке F1 = 75.5.
# Для того, чтобы получить такой результат, мы немного снизили patience и параметр min_delta. Таким образом, мы позволили сети продолжать обучаться даже при небольшом увеличении качества на валидационной выборке, но при этом за счет сокращения количества итераций без увеличения качества на min_delta, предотвратили переобучение модели.
# Финальная модель способна распознать 70% токсичных комментариев из всех токсичных комментариев, которые есть. При этом, среди тех комментариев, которые она распознала как токсичные, модель ошибается лишь в 18% случаев.

# %% [markdown]
# ## 5. Выводы

# %% [markdown]
# Целью данного проекта являлось построить модель, способную классифицировать комментарии как позитивные и негативные.
# В ходе работы над проектом были проделаны следующие шаги:
# - Предложения из корпуса были преобразованы в эмбеддинги при помощи модели BERT
# - Было проверено качество работы 4-х моделей на 10-fold кросс-валидации. Были получены следующие результаты:
#
# |Модель|F1 mean |F1 std|
# |-----|-----|-----|
# |LogisticRegression|0.742|0.007|
# |RandomForest|0.6|0.009|
# |CatBoost| 0.726|0.007|
# |NeuralNet|0.732|0.01|
# |NeuralNet #nobatch|0.724|0.02|
#
#
# - Следующим шагом был осуществлен подбор гиперпараметров для модели нейронной сети. На данном этапе удалось улучшить качество модели с 0.73 до 0.75 на 3-fold кросс валидации и до 74.9 на 10-fold кросс-валидации. При этом удалось снизить стандартное отклонение с 0.013 до 0.008.
# - На следующем этапе финальная модель была проверена на тестовом наборе данных. Качество ее работы составило 0.755 по F1-метрике.
